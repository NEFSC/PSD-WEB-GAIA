# %% [markdown]
# # Quality Assurance & Control - GeoDjango Objects
# Helps assure that the SQLite tables are spatially enabled, i.e. SpatiaLite, and are properly modeled by GeoDjango. This notebook also documents a lot of the validation needed to configure GeoDjango components.
#
# ### Configuring SpatiaLite and enabling GeoDjango
# Within `settings.py` the following need to be configured:
# - "GDAL_LIBRARY_PATH"
# - "SPATIALITE_LIBRARY_PATH"
# Also within `settings.py` "INSTALLED_APPS" needs to be amended to include `'django.contrib.gis'` and the "DATABASES" 'ENGINE' needs to be amended to be `'django.contrib.gis.db.backends.spatialite'`.
#
# At `[PROJECT]/` you need to download and unzip SpatiaLite from [here](https://www.gaia-gis.it/gaia-sins/) as well as make the amendments to your `libgdal.py` recommended in [this](https://stackoverflow.com/questions/46313119/geodjango-could-not-find-gdal-library-in-windows-10) StackOverflow post.
#
# ### Spatially Enabling Django Database
# Use the following code as a template to spatially enable your Django SQLite database turning it into a SpatiaLite database and therefore making your application a GeoDjango application. This code builds the metadata tables for spatial data.
#
# ```python
# import sqlite3
#
# db = "path/to/django/database/db.sqlite3"
#
# conn = sqlite3.connect(db)
# conn.enable_load_extension(True)
# conn.execute("SELECT load_extension('mod_spatialite')")
#
# c = conn.cursor()
# c.execute('''SELECT InitSpatialMetaData();''')
# conn.commit()
# conn.close()
# ```
#
# ### Validating SpatiaLite and GeoDjango
# From an Anaconda prompt window, activate your environment of choice and nagivate to your GeoDjango database. Here issue a command something like `sqlite3 db.sqlite3` which will turn your Anaconda prompt into a sqlite terminal. From here issue the command `.tables` you should see a bunch of geometry tables among others. Quit this termainl with `.quit`.
#
# From the Anaconda prompt, activate a GeoDjango Database Shell terminal with `python manage.py dbshell` this should launch you into a spatialite terminal. Quit out of this termainl with `.quit`.
#
# From the Anaconda prompt, activate a GeoDjango Shell terminal with `python manage.py shell`. At this point, we just want to make sure this starts up and will validate what should come out of here below since we are doing commands here, in the Jupyter Notebook, that could otherwise be implimented within the Shell terminal.
#
# ### Import some libraries, configure Django
# Since we are within Jupyter Notebook, some stuff has to be configured specifically to handle this development environment.

# %%
# Basic stack
import os

# Geospatial stack
import shapely
from shapely.wkt import loads
from shapely.geometry import Polygon
import pandas as pd
import geopandas as gpd
import folium

# GeoDjango stack
import sqlite3
import django
from django.db import connection
from django.contrib.gis.geos import GEOSGeometry
from asgiref.sync import sync_to_async

import sys; sys.path.append('../../')
os.environ['DJANGO_SETTINGS_MODULE'] = 'gaia.settings'
django.setup()

from whale.models import AreaOfInterest as AOI
from whale.models import ExtractTransformLoad as ETL

# %% [markdown]
# ### User defined variables

# %%
db = "../../db.sqlite3"
whale_earthexplorer_columns = ['entity_id', 'catalog_id', 'acquisition_date', 'vendor',
                               'vendor_id', 'cloud_cover', 'satellite', 'sensor',
                               'number_of_bands', 'map_projection', 'datum',
                               'processing_level', 'file_format', 'license_id',
                               'sun_azimuth', 'sun_elevation', 'pixel_size_x',
                               'pixel_size_y', 'license_uplift_update', 'event',
                               'date_entered', 'center_latitude_dec',
                               'center_longitude_dec', 'thumbnail', 'publish_date',
                               'aoi_id_id', 'event_date']
whale_areaofinterest_columns = ['id', 'name', 'requestor', 'sqkm']
etl_columns = ['table_name', 'aoi_id', 'id', 'vendor_id', 'entity_id', 'vendor',
               'platform', 'pixel_size_x', 'pixel_size_y', 'date', 'publish_date',
               'sea_state_qual', 'sea_state_quant', 'shareable']

# %% [markdown]
# ### Validate geospatial data within the SpatiaLite database

# %%
# Connect to database, load SpatiaLite exntention
conn = sqlite3.connect(db)
conn.enable_load_extension(True)
conn.execute("SELECT load_extension('mod_spatialite')")

# Using the column names within Whale's EarthExplorer table, select first ten records
columns_str = ', '.join(whale_earthexplorer_columns)
sql_string = "SELECT {}, AsText(bounds) FROM whale_earthexplorer LIMIT 10".format(columns_str)
df = pd.read_sql_query(sql_string, conn)

# Build GeoDataFrame from results
df = df.rename(columns={'AsText(bounds)': 'geometry'}, errors='raise')
df['geometry'] = shapely.wkt.loads(df['geometry'])
gdf = gpd.GeoDataFrame(df, geometry='geometry')

# Close your database connection
conn.commit()
conn.close()

# Show records
gdf.head()
# Out:
#               entity_id        catalog_id acquisition_date  \
# 0  WV320240510151159M00  10400100959B5400       2024-05-10
# 1  WV320240510151159P00  10400100959B5400       2024-05-10
# 2  WV320240510151200M00  10400100959B5400       2024-05-10
# 3  WV320240510151200P00  10400100959B5400       2024-05-10
# 4  WV320240510151201M00  10400100959B5400       2024-05-10
#
#                vendor                                vendor_id  cloud_cover  \
# 0  MAXAR TECHNOLOGIES  24MAY10151159-M1BS-508496072030_01_P001           76
# 1  MAXAR TECHNOLOGIES  24MAY10151159-P1BS-508496072030_01_P001           76
# 2  MAXAR TECHNOLOGIES  24MAY10151200-M1BS-508496072030_01_P002           50
# 3  MAXAR TECHNOLOGIES  24MAY10151200-P1BS-508496072030_01_P002           50
# 4  MAXAR TECHNOLOGIES  24MAY10151201-M1BS-508496072030_01_P003           23
#
#      satellite sensor  number_of_bands map_projection  ...  \
# 0  WORLDVIEW-3    MSI                8            GCP  ...
# 1  WORLDVIEW-3    PAN                1            GCP  ...
# 2  WORLDVIEW-3    MSI                8            GCP  ...
# 3  WORLDVIEW-3    PAN                1            GCP  ...
# 4  WORLDVIEW-3    MSI                8            GCP  ...
#
#   license_uplift_update  event date_entered  center_latitude_dec  \
# 0                  None  UCDAM   2024-05-21            41.867831
# 1                  None  UCDAM   2024-05-21            41.867839
# 2                  None  UCDAM   2024-05-21            41.932398
# 3                  None  UCDAM   2024-05-21            41.932406
# 4                  None  UCDAM   2024-05-21            41.997315
#
#    center_longitude_dec                                          thumbnail  \
# 0            -70.227235  https://ims.cr.usgs.gov/thumbnail/CRSSP/WV/202...
# 1            -70.227219  https://ims.cr.usgs.gov/thumbnail/CRSSP/WV/202...
# 2            -70.227268  https://ims.cr.usgs.gov/thumbnail/CRSSP/WV/202...
# 3            -70.227252  https://ims.cr.usgs.gov/thumbnail/CRSSP/WV/202...
# 4            -70.227204  https://ims.cr.usgs.gov/thumbnail/CRSSP/WV/202...
#
#                  publish_date  aoi_id_id event_date  \
# 0  2024-05-21 13:51:35.011890          6       None
# 1  2024-05-21 13:51:36.918914          6       None
# 2  2024-05-21 13:52:06.426599          6       None
# 3  2024-05-21 13:51:38.676543          6       None
# 4  2024-05-21 13:51:37.779161          6       None
#
#                                             geometry
# 0  POLYGON ((-70.36047 41.80772, -70.36047 41.927...
# 1  POLYGON ((-70.36013 41.80775, -70.36013 41.927...
# 2  POLYGON ((-70.36083 41.87082, -70.36083 41.993...
# 3  POLYGON ((-70.36050 41.87085, -70.36050 41.993...
# 4  POLYGON ((-70.36117 41.93425, -70.36117 42.060...
#
# [5 rows x 28 columns]

# %% [markdown]
# ### Plot GeoDataFrame on an interactive map

# %%
def style_function(hex_value):
    return {'color': hex_value, 'fillOpacity': 0}

# Add OpenStreetMap as a basemap
map = folium.Map()
folium.TileLayer('openstreetmap').add_to(map)

# Create a GeoJson layer from the response_geojson and add it to the map
folium.GeoJson(
    gdf['geometry'].to_json(),
    style_function = lambda x: style_function('#0000FF')
).add_to(map)

# Zoom to collected images
map.fit_bounds(map.get_bounds(), padding=(100, 100))

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_70518a7c1d888e009906533b51fbdb81 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_70518a7c1d888e009906533b51fbdb81&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_70518a7c1d888e009906533b51fbdb81 = L.map(
#                 &quot;map_70518a7c1d888e009906533b51fbdb81&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8ee9a53ce9befbf69002c64167ab91a8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8ee9a53ce9befbf69002c64167ab91a8.addTo(map_70518a7c1d888e009906533b51fbdb81);
#
#
#             var tile_layer_a0a0e46a1b84e3eb96b63717b2705689 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a0a0e46a1b84e3eb96b63717b2705689.addTo(map_70518a7c1d888e009906533b51fbdb81);
#
#
#         function geo_json_80a528c102b6e73ce7b72a27f91458e2_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#0000FF&quot;, &quot;fillOpacity&quot;: 0};
#             }
#         }
#
#         function geo_json_80a528c102b6e73ce7b72a27f91458e2_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_80a528c102b6e73ce7b72a27f91458e2 = L.geoJson(null, {
#                 onEachFeature: geo_json_80a528c102b6e73ce7b72a27f91458e2_onEachFeature,
#
#                 style: geo_json_80a528c102b6e73ce7b72a27f91458e2_styler,
#         });
#
#         function geo_json_80a528c102b6e73ce7b72a27f91458e2_add (data) {
#             geo_json_80a528c102b6e73ce7b72a27f91458e2
#                 .addData(data);
#         }
#             geo_json_80a528c102b6e73ce7b72a27f91458e2_add({&quot;bbox&quot;: [-70.361726, 41.807725, -70.092776, 42.147059], &quot;features&quot;: [{&quot;bbox&quot;: [-70.360465, 41.807725, -70.094004, 41.927938], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-70.360465, 41.807725], [-70.360465, 41.927938], [-70.094004, 41.927938], [-70.094004, 41.807725], [-70.360465, 41.807725]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-70.360134, 41.807752, -70.094304, 41.927927], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-70.360134, 41.807752], [-70.360134, 41.927927], [-70.094304, 41.927927], [-70.094304, 41.807752], [-70.360134, 41.807752]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-70.360829, 41.870817, -70.093706, 41.993979], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-70.360829, 41.870817], [-70.360829, 41.993979], [-70.093706, 41.993979], [-70.093706, 41.870817], [-70.360829, 41.870817]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-70.360496, 41.870846, -70.094007, 41.993965], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-70.360496, 41.870846], [-70.360496, 41.993965], [-70.094007, 41.993965], [-70.094007, 41.870846], [-70.360496, 41.870846]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-70.361174, 41.934253, -70.093235, 42.060377], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-70.361174, 41.934253], [-70.361174, 42.060377], [-70.093235, 42.060377], [-70.093235, 41.934253], [-70.361174, 41.934253]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-70.360841, 41.934285, -70.093538, 42.06036], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-70.360841, 41.934285], [-70.360841, 42.06036], [-70.093538, 42.06036], [-70.093538, 41.934285], [-70.360841, 41.934285]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;5&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-70.361598, 41.998025, -70.092909, 42.127234], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-70.361598, 41.998025], [-70.361598, 42.127234], [-70.092909, 42.1

# %% [markdown]
# ### Leverage GeoDjango's models to retrieve database objects
# GeoDjango's `models.py` file provides GeoDjango with a blueprint for how the application should interact with the database returning objects. This means datatypes, constraints, etc. need to match between the models and the database. If not, there is no guarantee the application will retrieve the information we desire if any information at all.
#
# Above, note that we used the table "whale_earthexplorer" where the application name is appended as a prefix to the model class. To validate that we can also retrieve the same information as objects let's import EarthExplorer from the Whale models and retrieve as well as plot this information.

# %%
from whale.models import EarthExplorer as EE

# Retrieve the first ten EarthExplorer objects from GeoDjango
imgs = await sync_to_async(list)(EE.objects.all()[:10])

# Create a GeoDataFrame
geoms = []
attributes = []
for img in imgs:
    attr_dict = {col: getattr(img, col) for col in whale_earthexplorer_columns}
    attributes.append(attr_dict)

    geoms.append(GEOSGeometry(img.bounds))

gdf = gpd.GeoDataFrame(attributes, geometry = [loads(g.wkt) for g in geoms])
gdf.head()
# Out:
#               entity_id        catalog_id acquisition_date  \
# 0  WV320240510151159M00  10400100959B5400       2024-05-10
# 1  WV320240510151159P00  10400100959B5400       2024-05-10
# 2  WV320240510151200M00  10400100959B5400       2024-05-10
# 3  WV320240510151200P00  10400100959B5400       2024-05-10
# 4  WV320240510151201M00  10400100959B5400       2024-05-10
#
#                vendor                                vendor_id  cloud_cover  \
# 0  MAXAR TECHNOLOGIES  24MAY10151159-M1BS-508496072030_01_P001           76
# 1  MAXAR TECHNOLOGIES  24MAY10151159-P1BS-508496072030_01_P001           76
# 2  MAXAR TECHNOLOGIES  24MAY10151200-M1BS-508496072030_01_P002           50
# 3  MAXAR TECHNOLOGIES  24MAY10151200-P1BS-508496072030_01_P002           50
# 4  MAXAR TECHNOLOGIES  24MAY10151201-M1BS-508496072030_01_P003           23
#
#      satellite sensor  number_of_bands map_projection  ...  \
# 0  WORLDVIEW-3    MSI                8            GCP  ...
# 1  WORLDVIEW-3    PAN                1            GCP  ...
# 2  WORLDVIEW-3    MSI                8            GCP  ...
# 3  WORLDVIEW-3    PAN                1            GCP  ...
# 4  WORLDVIEW-3    MSI                8            GCP  ...
#
#   license_uplift_update  event date_entered  center_latitude_dec  \
# 0                  None  UCDAM   2024-05-21            41.867831
# 1                  None  UCDAM   2024-05-21            41.867839
# 2                  None  UCDAM   2024-05-21            41.932398
# 3                  None  UCDAM   2024-05-21            41.932406
# 4                  None  UCDAM   2024-05-21            41.997315
#
#    center_longitude_dec                                          thumbnail  \
# 0            -70.227235  https://ims.cr.usgs.gov/thumbnail/CRSSP/WV/202...
# 1            -70.227219  https://ims.cr.usgs.gov/thumbnail/CRSSP/WV/202...
# 2            -70.227268  https://ims.cr.usgs.gov/thumbnail/CRSSP/WV/202...
# 3            -70.227252  https://ims.cr.usgs.gov/thumbnail/CRSSP/WV/202...
# 4            -70.227204  https://ims.cr.usgs.gov/thumbnail/CRSSP/WV/202...
#
#                       publish_date  aoi_id_id event_date  \
# 0 2024-05-21 13:51:35.011890+00:00          6       None
# 1 2024-05-21 13:51:36.918914+00:00          6       None
# 2 2024-05-21 13:52:06.426599+00:00          6       None
# 3 2024-05-21 13:51:38.676543+00:00          6       None
# 4 2024-05-21 13:51:37.779161+00:00          6       None
#
#                                             geometry
# 0  POLYGON ((-70.36047 41.80772, -70.36047 41.927...
# 1  POLYGON ((-70.36013 41.80775, -70.36013 41.927...
# 2  POLYGON ((-70.36083 41.87082, -70.36083 41.993...
# 3  POLYGON ((-70.36050 41.87085, -70.36050 41.993...
# 4  POLYGON ((-70.36117 41.93425, -70.36117 42.060...
#
# [5 rows x 28 columns]

# %% [markdown]
# ### Plot the results

# %%
def style_function(hex_value):
    return {'color': hex_value, 'fillOpacity': 0}

# Add OpenStreetMap as a basemap
map = folium.Map()
folium.TileLayer('openstreetmap').add_to(map)

# Create a GeoJson layer from the response_geojson and add it to the map
folium.GeoJson(
    gdf['geometry'].to_json(),
    style_function = lambda x: style_function('#0000FF')
).add_to(map)

# Zoom to collected images
map.fit_bounds(map.get_bounds(), padding=(100, 100))

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bbfa16c696bcad82766d58ad7ab54853 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bbfa16c696bcad82766d58ad7ab54853&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bbfa16c696bcad82766d58ad7ab54853 = L.map(
#                 &quot;map_bbfa16c696bcad82766d58ad7ab54853&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c71cdeed150a609043cacd90e84bc801 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c71cdeed150a609043cacd90e84bc801.addTo(map_bbfa16c696bcad82766d58ad7ab54853);
#
#
#             var tile_layer_7ef2c41f1b9978406ceb985ee317a02c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7ef2c41f1b9978406ceb985ee317a02c.addTo(map_bbfa16c696bcad82766d58ad7ab54853);
#
#
#         function geo_json_41d5b8533058288a14ce3f4b37e8fbd5_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#0000FF&quot;, &quot;fillOpacity&quot;: 0};
#             }
#         }
#
#         function geo_json_41d5b8533058288a14ce3f4b37e8fbd5_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_41d5b8533058288a14ce3f4b37e8fbd5 = L.geoJson(null, {
#                 onEachFeature: geo_json_41d5b8533058288a14ce3f4b37e8fbd5_onEachFeature,
#
#                 style: geo_json_41d5b8533058288a14ce3f4b37e8fbd5_styler,
#         });
#
#         function geo_json_41d5b8533058288a14ce3f4b37e8fbd5_add (data) {
#             geo_json_41d5b8533058288a14ce3f4b37e8fbd5
#                 .addData(data);
#         }
#             geo_json_41d5b8533058288a14ce3f4b37e8fbd5_add({&quot;bbox&quot;: [-70.361726, 41.807725, -70.092776, 42.147059], &quot;features&quot;: [{&quot;bbox&quot;: [-70.360465, 41.807725, -70.094004, 41.927938], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-70.360465, 41.807725], [-70.360465, 41.927938], [-70.094004, 41.927938], [-70.094004, 41.807725], [-70.360465, 41.807725]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-70.360134, 41.807752, -70.094304, 41.927927], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-70.360134, 41.807752], [-70.360134, 41.927927], [-70.094304, 41.927927], [-70.094304, 41.807752], [-70.360134, 41.807752]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-70.360829, 41.870817, -70.093706, 41.993979], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-70.360829, 41.870817], [-70.360829, 41.993979], [-70.093706, 41.993979], [-70.093706, 41.870817], [-70.360829, 41.870817]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-70.360496, 41.870846, -70.094007, 41.993965], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-70.360496, 41.870846], [-70.360496, 41.993965], [-70.094007, 41.993965], [-70.094007, 41.870846], [-70.360496, 41.870846]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-70.361174, 41.934253, -70.093235, 42.060377], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-70.361174, 41.934253], [-70.361174, 42.060377], [-70.093235, 42.060377], [-70.093235, 41.934253], [-70.361174, 41.934253]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-70.360841, 41.934285, -70.093538, 42.06036], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-70.360841, 41.934285], [-70.360841, 42.06036], [-70.093538, 42.06036], [-70.093538, 41.934285], [-70.360841, 41.934285]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;5&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-70.361598, 41.998025, -70.092909, 42.127234], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-70.361598, 41.998025], [-70.361598, 42.127234], [-70.092909, 42.1

# %% [markdown]
# ### Let's confirm the above code works for other models like AOI

# %%
# Retrieve the first ten EarthExplorer objects from GeoDjango
imgs = await sync_to_async(list)(AOI.objects.all()[:10])

# Create a GeoDataFrame
geoms = []
attributes = []
for img in imgs:
    attr_dict = {col: getattr(img, col) for col in whale_areaofinterest_columns}
    attributes.append(attr_dict)

    geoms.append(GEOSGeometry(img.geometry))

gdf = gpd.GeoDataFrame(attributes, geometry = [loads(g.wkt) for g in geoms])
gdf.head()
# Out:
#    id           name requestor     sqkm  \
# 0   1          Kenai             416.53
# 1   2  Kalgin Island             884.65
# 2   3    Trading Bay             529.37
# 3   4        Tuxedni             438.72
# 4   5       Upper CI            1871.28
#
#                                             geometry
# 0  POLYGON ((-151.59303 60.32094, -151.43153 60.6...
# 1  POLYGON ((-151.73795 60.71243, -151.69676 60.5...
# 2  POLYGON ((-151.34361 61.01015, -151.22669 60.9...
# 3  POLYGON ((-152.60081 60.02992, -152.59393 60.0...
# 4  POLYGON ((-150.67303 60.95571, -151.00321 61.1...

# %% [markdown]
# ### Plot the results

# %%
def style_function(hex_value):
    return {'color': hex_value, 'fillOpacity': 0}

# Add OpenStreetMap as a basemap
map = folium.Map()
folium.TileLayer('openstreetmap').add_to(map)

# Create a GeoJson layer from the response_geojson and add it to the map
folium.GeoJson(
    gdf['geometry'].to_json(),
    style_function = lambda x: style_function('#0000FF')
).add_to(map)

# Zoom to collected images
map.fit_bounds(map.get_bounds(), padding=(100, 100))

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_755eb92c77565a4cb71eff11ee78b0c2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_755eb92c77565a4cb71eff11ee78b0c2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_755eb92c77565a4cb71eff11ee78b0c2 = L.map(
#                 &quot;map_755eb92c77565a4cb71eff11ee78b0c2&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c77482963ded4bfd3f3fda35979fc78a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c77482963ded4bfd3f3fda35979fc78a.addTo(map_755eb92c77565a4cb71eff11ee78b0c2);
#
#
#             var tile_layer_4c42a793bc74924ff91bf21be8672d69 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4c42a793bc74924ff91bf21be8672d69.addTo(map_755eb92c77565a4cb71eff11ee78b0c2);
#
#
#         function geo_json_90a359203bb26dd1253e6ab4123dbfc5_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#0000FF&quot;, &quot;fillOpacity&quot;: 0};
#             }
#         }
#
#         function geo_json_90a359203bb26dd1253e6ab4123dbfc5_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_90a359203bb26dd1253e6ab4123dbfc5 = L.geoJson(null, {
#                 onEachFeature: geo_json_90a359203bb26dd1253e6ab4123dbfc5_onEachFeature,
#
#                 style: geo_json_90a359203bb26dd1253e6ab4123dbfc5_styler,
#         });
#
#         function geo_json_90a359203bb26dd1253e6ab4123dbfc5_add (data) {
#             geo_json_90a359203bb26dd1253e6ab4123dbfc5
#                 .addData(data);
#         }
#             geo_json_90a359203bb26dd1253e6ab4123dbfc5_add({&quot;bbox&quot;: [-152.749985, 41.534581, -69.301335, 61.400036], &quot;features&quot;: [{&quot;bbox&quot;: [-151.593025, 60.299495, -151.221649, 60.698672], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-151.593025, 60.320938], [-151.431526, 60.698672], [-151.414078, 60.69755], [-151.405518, 60.680618], [-151.385742, 60.657486], [-151.384216, 60.655697], [-151.364304, 60.638313], [-151.357895, 60.61866], [-151.359787, 60.610443], [-151.354324, 60.593536], [-151.342804, 60.577755], [-151.325714, 60.563568], [-151.306747, 60.555996], [-151.285904, 60.550472], [-151.282959, 60.550529], [-151.242752, 60.551289], [-151.236328, 60.543736], [-151.241943, 60.539639], [-151.256363, 60.534649], [-151.256439, 60.525742], [-151.250885, 60.524361], [-151.234161, 60.528431], [-151.221649, 60.528172], [-151.221664, 60.525429], [-151.234665, 60.524319], [-151.247665, 60.521156], [-151.254181, 60.519573], [-151.266647, 60.525082], [-151.272598, 60.533772], [-151.270233, 60.539021], [-151.265579, 60.541294], [-151.255844, 60.540813], [-151.248383, 60.544449], [-151.251144, 60.547199], [-151.26181, 60.54768], [-151.271561, 60.545647], [-151.278091, 60.542007], [-151.29689, 60.509842], [-151.296616, 60.485405], [-151.298843, 60.475819], [-151.307129, 60.439972], [-151.306778, 60.4249], [-151.314331, 60.401157], [-151.30983, 60.386532], [-151.300171, 60.381718], [-151.31636, 60.376041], [-151.31308, 60.383343], [-151.32135, 60.387695], [-151.326889, 60.387936], [-151.348648, 60.378376], [-151.36528, 60.376575], [-151.370285, 60.374599], [-151.388397, 60.367474], [-151.401047, 60.322041], [-151.396515, 60.306282], [-151.398321, 60.299495], [-151.593025, 60.320938]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-152.33905, 60.367845, -151.696757, 60.751831], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-151.737948, 60.712428], [-151.696757, 60.521927], [-151.732147, 60.45267], [-151.96557, 60.378934], [-151.97316, 60.383652], [-151.980713, 60.395741], [-151.99086, 60.395023], [-151.992737, 60.397072], [-151.978958, 60.403053], [-151.959274, 60.417267], [-151.959167, 60.418072], [-151.958435, 60.422981], [-151.930405, 60.437675], [-151.909149, 60.438644], [-151.89946, 60.440952], [-151.893433, 60.438911], [-151.890259, 60.443943], [-151.890793, 60.451252], [-151.898788, 60.463566], [-151.895142, 60.468369], [-151.864243, 60.480545], [-151.83606, 60.487], [-151.840271, 60.491558], [-151.856705, 60.498199], [-151.864456, 6

# %% [markdown]
# ### Now, let's repeat this for the ExtractTransformLoad (ETL) Table
# Note that the ETL table is a table created from other table. I've seen this described as a junction or denormalized table amongst others. The key point is that this table integrates imagery across our three data sources (USGS EarthExplorer, GEGD, and Maxar Geospatial Platform) into a uniform table. As such, you'll notice there is no "whale_" prefix. Records are added to the table from triggers. This is the table we want to ensure always passes QA/QC.

# %%
# Retrieve the first 25 EarthExplorer objects from GeoDjango
imgs = await sync_to_async(list)(ETL.objects.all()[:25])

# Create a GeoDataFrame
geoms = []
attributes = []
for img in imgs:
    attr_dict = {col: getattr(img, col) for col in etl_columns}
    attributes.append(attr_dict)

    geoms.append(GEOSGeometry(img.geometry))

gdf = gpd.GeoDataFrame(attributes, geometry = [loads(g.wkt) for g in geoms])
gdf.head(25)
# Out:
#    table_name  aoi_id                id  \
# 0          EE       6  104001003D6A7700
# 1          EE       6  104001003D6A7700
# 2          EE       6  104001003D6A7700
# 3          EE       6  104001003D6A7700
# 4          EE       6  104001003D6A7700
# 5          EE       6  104001003D6A7700
# 6          EE       6  104001003D6A7700
# 7          EE       6  104001003D6A7700
# 8          EE       6  10400100470C8300
# 9          EE       6  10400100470C8300
# 10         EE       6  10400100470C8300
# 11         EE       6  10400100470C8300
# 12         EE       6  10400100470C8300
# 13         EE       6  10400100470C8300
# 14         EE       6  10400100470C8300
# 15         EE       6  10400100470C8300
# 16         EE       6  10400100470C8300
# 17         EE       6  10400100470C8300
# 18         EE       6  10400100470C8300
# 19         EE       6  10400100470C8300
# 20         EE       6  10400100470C8300
# 21         EE       6  10400100470C8300
# 22         EE       6  10400100476C3000
# 23         EE       6  10400100476C3000
# 24         EE       6  10400100476C3000
#
#                                        vendor_id                   entity_id  \
# 0        18MAY24154658-M1BS-503577655070_01_P001        WV320180524154658M00
# 1        18MAY24154658-P1BS-503577655070_01_P001        WV320180524154658P00
# 2        18MAY24154659-M1BS-503577655070_01_P002        WV320180524154659M00
# 3        18MAY24154659-P1BS-503577655070_01_P002        WV320180524154659P00
# 4        18MAY24154701-M1BS-503577655070_01_P003        WV320180524154701M00
# 5        18MAY24154701-P1BS-503577655070_01_P003        WV320180524154701P00
# 6        18MAY24154703-M1BS-503577655070_01_P004        WV320180524154703M00
# 7        18MAY24154703-P1BS-503577655070_01_P004        WV320180524154703P00
# 8   19FEB25160014-S2AS_R1C2-504979755010_01_P008  WV320190225160014OR01C0200
# 9   19FEB25160015-S2AS_R1C2-504979755010_01_P009  WV320190225160015OR01C0200
# 10  19FEB25160015-S2AS_R2C2-504979755010_01_P009  WV320190225160015OR02C0200
# 11  19FEB25160016-S2AS_R1C2-504979755010_01_P010  WV320190225160016OR01C0200
# 12  19FEB25160016-S2AS_R2C2-504979755010_01_P010  WV320190225160016OR02C0200
# 13  19FEB25160017-S2AS_R1C2-504979755010_01_P011  WV320190225160017OR01C0200
# 14  19FEB25160017-S2AS_R2C2-504979755010_01_P011  WV320190225160017OR02C0200
# 15  19FEB25160018-S2AS_R1C2-504979755010_01_P012  WV320190225160018OR01C0200
# 16  19FEB25160018-S2AS_R2C2-504979755010_01_P012  WV320190225160018OR02C0200
# 17  19FEB25160019-S2AS_R1C2-504979755010_01_P013  WV320190225160019OR01C0200
# 18  19FEB25160019-S2AS_R2C2-504979755010_01_P013  WV320190225160019OR02C0200
# 19  19FEB25160020-S2AS_R1C2-504979755010_01_P014  WV320190225160020OR01C0201
# 20  19FEB25160020-S2AS_R1C2-504979755010_01_P015  WV320190225160020OR01C0200
# 21  19FEB25160020-S2AS_R2C2-504979755010_01_P014  WV320190225160020OR02C0200
# 22  19FEB25160125-S2AS_R1C2-504979755020_01_P009  WV320190225160125OR01C0200
# 23  19FEB25160126-S2AS_R1C2-504979755020_01_P010  WV320190225160126OR01C0200
# 24  19FEB25160126-S2AS_R2C2-504979755020_01_P010  WV320190225160126OR02C0200
#
#            vendor     platform  pixel_size_x  pixel_size_y        date  \
# 0   DIGITAL GLOBE  WORLDVIEW-3             1             1  2018-05-24
# 1   DIGITAL GLOBE  WORLDVIEW-3             0             0  2018-05-24
# 2   DIGITAL GLOBE  WORLDVIEW-3             1             1  2018-05-24
# 3   DIGITAL GLOBE  WORLDVIEW-3             0             0  2018-05-24
# 4   DIGITAL GLOBE  WORLDVIEW-3             1             1  2018-05-24
# 5   DIGITAL GLOBE  WORLDVIEW-3             0             0  2018-05-24
# 6   DIGITAL GLOBE  WORLDVIEW-3             1             1  2018-05-24
# 7   DIGITAL GLOBE  WORLDVIEW-3             0             0  2018-05-24
# 8   DIGITAL GLOBE  WORLDVIEW-3             1             1  2019-02-25
# 9   DIGITAL GLOBE  WORLDVIEW-3             1             1  2019-02-25
# 10  DIGITAL GLOBE  WORLDVIEW-3             1             1  2019-02-25
# 11  DIGITAL GLOBE  WORLDVIEW-3             1             1  2019-02-25
# 12  DIGITAL GLOBE  WORLDVIEW-3             1             1  2019-02-25
# 13  DIGITAL GLOBE  WORLDVIEW-3             1             1  2019-02-25
# 14  DIGITAL GLOBE  WORLDVIEW-3             1             1  2019-02-25
# 15  DIGITAL GLOBE  WORLDVIEW-3             1             1  2019-02-25
# 16  DIGITAL GLOBE  WORLDVIEW-3             1             1  2019-02-25
# 17  DIGITAL GLOBE  WORLDVIEW-3             1             1  2019-02-25
# 18  DIGITAL GLOBE  WORLDVIEW-3             1             1  2019-02-25
# 19  DIGITAL GLOBE  WORLDVIEW-3             1             1  2019-02-25
# 20  DIGITAL GLOBE  WORLDVIEW-3             1             1  2019-02-25
# 21  DIGITAL GLOBE  WORLDVIEW-3             1             1  2019-02-25
# 22  DIGITAL GLOBE  WORLDVIEW-3             1             1  2019-02-25
# 23  DIGITAL GLOBE  WORLDVIEW-3             1             1  2019-02-25
# 24  DIGITAL GLOBE  WORLDVIEW-3             1             1  2019-02-25
#
#    publish_date sea_state_qual sea_state_quant shareable  \
# 0    2019-10-03           None            None      None
# 1    2019-10-03           None            None      None
# 2    2019-10-03           None            None      None
# 3    2019-10-03           None            None      None
# 4    2019-10-03           None            None      None
# 5    2019-10-03           None            None      None
# 6    2019-10-03           None            None      None
# 7    2019-10-03           None            None      None
# 8    2021-02-15           None            None      None
# 9    2021-02-15           None            None      None
# 10   2021-02-15           None            None      None
# 11   2021-02-15           None            None      None
# 12   2021-02-15           None            None      None
# 13   2021-02-15           None            None      None
# 14   2021-02-15           None            None      None
# 15   2021-02-15           None            None      None
# 16   2021-02-15           None            None      None
# 17   2021-02-15           None            None      None
# 18   2021-02-15           None            None      None
# 19   2021-02-15           None            None      None
# 20   2021-02-15           None            None      None
# 21   2021-02-15           None            None      None
# 22   2021-02-15           None            None      None
# 23   2021-02-15           None            None      None
# 24   2021-02-15           None            None      None
#
#                                              geometry
# 0   POLYGON ((-70.60444 42.02472, -70.60444 42.169...
# 1   POLYGON ((-70.60417 42.02472, -70.60417 42.169...
# 2   POLYGON ((-70.60389 41.91444, -70.60389 42.069...
# 3   POLYGON ((-70.60361 41.91444, -70.60361 42.069...
# 4   POLYGON ((-70.60333 41.80444, -70.60333 41.958...
# 5   POLYGON ((-70.60306 41.80444, -70.60306 41.958...
# 6   POLYGON ((-70.60250 41.69444, -70.60250 41.848...
# 7   POLYGON ((-70.60222 41.69444, -70.60222 41.848...
# 8   POLYGON ((-70.53804 41.69054, -70.53804 41.765...
# 9   POLYGON ((-70.53715 41.75280, -70.53715 41.827...
# 10  POLYGON ((-70.53539 41.72769, -70.53539 41.753...
# 11  POLYGON ((-70.53625 41.81394, -70.53625 41.888...
# 12  POLYGON ((-70.53449 41.79073, -70.53449 41.814...
# 13  POLYGON ((-70.53545 41.87404, -70.53545 41.948...
# 14  POLYGON ((-70.53369 41.85264, -70.53369 41.875...
# 15  POLYGON ((-70.53467 41.93317, -70.53467 42.007...
# 16  POLYGON ((-70.53291 41.91344, -70.53291 41.934...
# 17  POLYGON ((-70.53393 41.99141, -70.53393 42.066...
# 18  POLYGON ((-70.53215 41.97323, -70.53215 41.992...
# 19  POLYGON ((-70.53320 42.04877, -70.53320 42.123...
# 20  POLYGON ((-70.53207 42.08997, -70.53207 42.160...
# 21  POLYGON ((-70.53143 42.03206, -70.53143 42.049...
# 22  POLYGON ((-70.53150 41.71565, -70.53150 41.790...
# 23  POLYGON ((-70.53215 41.78340, -70.53215 41.858...
# 24  POLYGON ((-70.53039 41.75086, -70.53039 41.784...

# %% [markdown]
# ### Plot the results

# %%
def style_function(hex_value):
    return {'color': hex_value, 'fillOpacity': 0}

# Add OpenStreetMap as a basemap
map = folium.Map()
folium.TileLayer('openstreetmap').add_to(map)

# Create a GeoJson layer from the response_geojson and add it to the map
folium.GeoJson(
    gdf['geometry'].to_json(),
    style_function = lambda x: style_function('#0000FF')
).add_to(map)

# Zoom to collected images
map.fit_bounds(map.get_bounds(), padding=(100, 100))

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2aa09fe766a67463f4e806e50199c1ac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2aa09fe766a67463f4e806e50199c1ac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2aa09fe766a67463f4e806e50199c1ac = L.map(
#                 &quot;map_2aa09fe766a67463f4e806e50199c1ac&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1b814e3d145b06521f5343bd3f3820ad = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1b814e3d145b06521f5343bd3f3820ad.addTo(map_2aa09fe766a67463f4e806e50199c1ac);
#
#
#             var tile_layer_281471e3fd4490ec13a9fcce7556d870 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_281471e3fd4490ec13a9fcce7556d870.addTo(map_2aa09fe766a67463f4e806e50199c1ac);
#
#
#         function geo_json_b64e62b00a2f65f3d521de74a38676f5_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#0000FF&quot;, &quot;fillOpacity&quot;: 0};
#             }
#         }
#
#         function geo_json_b64e62b00a2f65f3d521de74a38676f5_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_b64e62b00a2f65f3d521de74a38676f5 = L.geoJson(null, {
#                 onEachFeature: geo_json_b64e62b00a2f65f3d521de74a38676f5_onEachFeature,
#
#                 style: geo_json_b64e62b00a2f65f3d521de74a38676f5_styler,
#         });
#
#         function geo_json_b64e62b00a2f65f3d521de74a38676f5_add (data) {
#             geo_json_b64e62b00a2f65f3d521de74a38676f5
#                 .addData(data);
#         }
#             geo_json_b64e62b00a2f65f3d521de74a38676f5_add({&quot;bbox&quot;: [-70.604444, 41.690537, -70.391944, 42.169167], &quot;features&quot;: [{&quot;bbox&quot;: [-70.604444, 42.024722, -70.391944, 42.169167], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-70.604444, 42.024722], [-70.604444, 42.169167], [-70.391944, 42.169167], [-70.391944, 42.024722], [-70.604444, 42.024722]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-70.604167, 42.024722, -70.392222, 42.169167], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-70.604167, 42.024722], [-70.604167, 42.169167], [-70.392222, 42.169167], [-70.392222, 42.024722], [-70.604167, 42.024722]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-70.603889, 41.914444, -70.3925, 42.069167], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-70.603889, 41.914444], [-70.603889, 42.069167], [-70.3925, 42.069167], [-70.3925, 41.914444], [-70.603889, 41.914444]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-70.603611, 41.914444, -70.392778, 42.069167], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-70.603611, 41.914444], [-70.603611, 42.069167], [-70.392778, 42.069167], [-70.392778, 41.914444], [-70.603611, 41.914444]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-70.603333, 41.804444, -70.393056, 41.958889], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-70.603333, 41.804444], [-70.603333, 41.958889], [-70.393056, 41.958889], [-70.393056, 41.804444], [-70.603333, 41.804444]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-70.603056, 41.804444, -70.393333, 41.958889], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-70.603056, 41.804444], [-70.603056, 41.958889], [-70.393333, 41.958889], [-70.393333, 41.804444], [-70.603056, 41.804444]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;5&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-70.6025, 41.694444, -70.393611, 41.848611], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-70.6025, 41.694444], [-70.6025, 41.848611], [-70.393611, 41.848611], [

# %% [markdown]
# # End
