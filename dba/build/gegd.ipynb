# %% [markdown]
# # Build (GEGD)
# Using an Area of Interest (AOI) from the `aoi` SQLite Database, queries the Global Enchanced GEOINT Delivery API for data over a given time period, builds the `gegd` table from these results, and then populates the table with these values. Other notebooks should be used for adding additional records to the table.
#
# ### Import libraries

# %%
# Basic stack
from datetime import datetime

# Web Stack
import json
import requests
import getpass

# Database stack
import sqlite3

# Data Science stack
import shapely
from shapely.geometry import box, Polygon
import pandas as pd
import geopandas as gpd
import folium

# Custom stack
import sys; sys.path.append("../../")
from MGP import security, search

# %% [markdown]
# ### User defined variables

# %%
aoi_id = '6'
start_date = '2014-08-13'
end_date = '2024-05-31'
db = "C:/gis/gaia/data/databases/gaia.db"
connect_id = 'eb33ba21-1782-4ffc-8a5c-4854e21effb9'

# %% [markdown]
# ### User defined functions

# %%
def update_gedg(c, iid, column_name, column_value):
    """ Updates GEGD table values of a given column with a given value using the 
            ID as the selection criteria for the update.

        C - A cursor
        ENTITY ID - An ID from  Global Enhanced GEOINT Delivery
        COLUMN NAME - A column name within the EE table to be updated
        COLUMN VALUE - A value to update the column
    """
    force_string_list = ['legacy_id', 'factory_order_number', 'source', 'source_unit',
                        'product_type', 'data_layer', 'legacy_description',
                        'color_band_order', 'asset_name', 'crs_from_pixels',
                        'company_name', 'copyright']
    force_date_list = ['acquisition_date', 'ingest_date']
    force_geom_list = ['geometry']
    
    if column_name in force_string_list:
        sql_string = f"UPDATE gegd SET {column_name} = \"{column_value}\" WHERE id = \"{iid}\""
        c.execute(sql_string)

    elif column_name in force_date_list:
        sql_string = f"UPDATE gegd SET {column_name} = "
        sql_string = sql_string + "? WHERE id = ?"
        c.execute(sql_string, (column_value, iid))
    
    elif column_name in force_geom_list:
        sql_string = f"UPDATE gegd SET {column_name} = GeomFromText(\"{column_value}\") WHERE id = \"{iid}\""
        c.execute(sql_string)
    
    else:
        sql_string = f"UPDATE gegd SET {column_name} = {column_value} WHERE id = \"{iid}\""
        c.execute(sql_string)

def database_activity(db, entity_id, column_name, column_value, activity='update'):
    """ Wrapper function for activities related to database management.
            Currently only supports UPDATING based on  Global Enhanced
            GEOINT Delivery ID values.

        Is dependent on the UPDATE GEGD function above.

        DB - A database target
        ENTITY ID - An  Global Enhanced GEOINT Delivery ID uniquely
            identifying the record of interest.
        COLUMN NAME - The column to be updated
        COLUMN VALUE - The value of the column to be updated
        ACTIVITY - The activity to be carried out. Currently only
            supports UPDATE.
    """
    conn = sqlite3.connect(db)
    conn.enable_load_extension(True)
    conn.execute("SELECT load_extension('mod_spatialite')")
    c = conn.cursor()

    if activity == 'update':
        try:
            update_gedg(c, entity_id, column_name, column_value)
        except Exception as e:
            print("Exception: {} was raised for ID {}".format(e, row['id']))
    else:
        print("Your activity method is not currently supported.")
    
    conn.commit()
    conn.close()

def insert_gedg(c, iid):
    """ Inserts Global Enhanced GEOINT Delivery IDs into the GEGD Data Table.
            The IDs are the Primary Key for the datatable since it is
            unique

        C - A cursor
        ID - An ID value from  Global Enhanced GEOINT Delivery
    """
    sql_string = f"INSERT INTO gegd(id) VALUES (\"{iid}\")"
    c.execute(sql_string)

# %% [markdown]
# ### Get Log-in details from user
# Hint: 1572183293; ???

# %%
username = input("Enter your username:  ")
password = getpass.getpass("Enter your password:  ")
# Out:
# Enter your username:   1572183293
# Enter your password:   ········

# %% [markdown]
# ### Retreve the Area of Interest record from the `aoi` table corresponding to the supplied DAR number

# %%
conn = sqlite3.connect(db)
conn.enable_load_extension(True)
conn.execute("SELECT load_extension('mod_spatialite')")

c = conn.cursor()

sql_string = f"SELECT aid, name, sqkm, AsText(geom) FROM aoi WHERE aid={aoi_id}"
df = pd.read_sql_query(sql_string, conn)
df = df.rename(columns={'AsText(geom)': 'geometry'}, errors='raise')
df['geometry'] = shapely.wkt.loads(df['geometry'])
gdf_aoi = gpd.GeoDataFrame(df, geometry='geometry')

conn.commit()
conn.close()

gdf_aoi
# Out:
#    aid          name     sqkm  \
# 0    6  Cape Cod Bay  1347.04
#
#                                             geometry
# 0  POLYGON ((-70.11938 42.10724, -70.52387 42.109...

# %% [markdown]
# ### Build Common Query Language (CQL) spatio-temporal filter

# %%
spatial_filter = "INTERSECTS(geometry, {})".format(gdf_aoi['geometry'][0].wkt)
temporal_filter = "acquisitionDate > {} AND acquisitionDate < {}".format(start_date, end_date) 
cql_filter = ' AND '.join([spatial_filter, temporal_filter])
cql_filter
# Out:
# 'INTERSECTS(geometry, POLYGON ((-70.119385 42.107239, -70.523865 42.109436, -70.526001 41.747925, -70.121399 41.745544, -70.119385 42.107239))) AND acquisitionDate > 2014-08-13 AND acquisitionDate < 2024-05-31'

# %% [markdown]
# ### Search MGP

# %%
url = 'https://evwhs.digitalglobe.com/catalogservice/wfsaccess'

params = {
    'service': 'WFS',
    'version': '2.0.0',
    'request': 'GetFeature',
    'typeName': 'DigitalGlobe:FinishedFeature',
    'outputFormat': 'application/json',
    'connectId': connect_id,
    'cql_filter': cql_filter
}

results = requests.get(url=url, params=params, auth=(username, password))
r = results.json()
r
# Out:
# {'type': 'FeatureCollection',
#  'totalFeatures': 3,
#  'features': [{'type': 'Feature',
#    'id': '574efe4bff88148b10f9043c889ff154',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[41.98936088, -69.989218],
#       [42.078879, -69.98882781],
#       [42.12444612, -69.98863615],
#       [42.1700126, -69.98843282],
#       [42.21586296, -69.98823966],
#       [42.26171265, -69.98803468],
#       [42.35249841, -69.98764233],
#       [42.35268538, -70.01865606],
#       [42.35287214, -70.0496697],
#       [42.35305868, -70.08068323],
#       [42.353245, -70.11169667],
#       [42.35343111, -70.14271001],
#       [42.353617, -70.17372326],
#       [42.35380267, -70.20473641],
#       [42.35398813, -70.23574947],
#       [42.35417337, -70.26676243],
#       [42.3543584, -70.29777529],
#       [42.35454321, -70.32878806],
#       [42.3547278, -70.35980074],
#       [42.35491219, -70.39081332],
#       [42.35509636, -70.4218258],
#       [42.35528031, -70.45283819],
#       [42.35546405, -70.48385048],
#       [42.35564758, -70.51486268],
#       [42.3558309, -70.54587479],
#       [42.35601401, -70.5768868],
#       [42.3561969, -70.60789871],
#       [42.35637958, -70.63891053],
#       [42.35656205, -70.66992226],
#       [42.35674432, -70.70093389],
#       [42.35692637, -70.73194543],
#       [42.35710821, -70.76295688],
#       [42.35728984, -70.79396823],
#       [42.35747127, -70.82497949],
#       [42.35765248, -70.85599066],
#       [42.35783349, -70.88700173],
#       [42.35801429, -70.91801271],
#       [42.35819488, -70.9490236],
#       [42.35837526, -70.98003439],
#       [42.35855544, -71.01104509],
#       [42.34469711, -71.01107358],
#       [42.25455511, -71.01118629],
#       [42.16441301, -71.01125533],
#       [42.07427121, -71.01128069],
#       [41.98413015, -71.01126238],
#       [41.98431088, -70.98029281],
#       [41.98449016, -70.94932316],
#       [41.98466801, -70.91835341],
#       [41.98484442, -70.88738357],
#       [41.98501941, -70.85641364],
#       [41.98519297, -70.82544362],
#       [41.98536512, -70.79447351],
#       [41.98553586, -70.76350331],
#       [41.9857052, -70.73253301],
#       [41.98587313, -70.70156262],
#       [41.98603967, -70.67059214],
#       [41.98620482, -70.63962157],
#       [41.98636858, -70.6086509],
#       [41.98653097, -70.57768015],
#       [41.98669198, -70.54670929],
#       [41.98685162, -70.51573835],
#       [41.9870099, -70.48476732],
#       [41.98716682, -70.45379619],
#       [41.98732239, -70.42282496],
#       [41.98747661, -70.39185365],
#       [41.98762948, -70.36088224],
#       [41.98778101, -70.32991074],
#       [41.98793121, -70.29893914],
#       [41.98808008, -70.26796745],
#       [41.98822763, -70.23699566],
#       [41.98837386, -70.20602379],
#       [41.98851877, -70.17505181],
#       [41.98866237, -70.14407975],
#       [41.98880466, -70.11310759],
#       [41.98894566, -70.08213533],
#       [41.98908535, -70.05116298],
#       [41.98922376, -70.02019054],
#       [41.98936088, -69.989218]]]},
#    'geometry_name': 'geometry',
#    'properties': {'featureId': '574efe4bff88148b10f9043c889ff154',
#     'acquisitionDate': '2023-10-01 06:02:38',
#     'acquisitionTime': 602,
#     'sensorType': '',
#     'source': 'WV03_VNIR',
#     'sourceUnit': 'Strip',
#     'productType': 'Pan Sharpened Natural Color',
#     'CE90Accuracy': None,
#     'RMSEAccuracy': None,
#     'cloudCover': 0,
#     'offNadirAngle': 7.1321855,
#     'sunElevation': 16.840834,
#     'sunAzimuth': 47.088608,
#     'groundSampleDistance': 0.32,
#     'groundSampleDistanceUnit': 'Meter',
#     'dataLayer': 'daily_take',
#     'legacyDescription': 'AOI14_L2_WV3',
#     'outputMosaic': False,
#     'colorBandOrder': 'RGB',
#     'assetName': 'FINISHED',
#     'assetType': 'PRODUCT_GEOMETRY',
#     'legacyId': '1040010089677300',
#     'factoryOrderNumber': '016024927-10',
#     'perPixelX': 0.32266899943351746,
#     'perPixelY': -0.32266899943351746,
#     'crsFromPixels': 'EPSG:32738',
#     'url': '',
#     'ageDays': 318,
#     'formattedDate': '2023-10-01',
#     'ingestDate': '2023-10-01 12:34:43',
#     'spatialAccuracy': '',
#     'earliestAcquisitionDate': '2023-10-01 06:02:38',
#     'latestAcquisitionDate': '2023-10-01 06:02:38',
#     'pixelsIngested': True,
#     'preciseGeometry': True,
#     'vendorName': '',
#     'vendorReference': '',
#     'companyName': 'DigitalGlobe',
#     'acquisitionType': '',
#     'orbitDirection': '',
#     'licenseType': '',
#     'isBrowse': False,
#     'isMirrored': False,
#     'isMultipleWKB': False,
#     'copyright': 'Image Copyright 2023 DigitalGlobe Inc',
#     'beamMode': '',
#     'polarisationMode': '',
#     'polarisationChannel': '',
#     'antennaLookDirection': '',
#     'minimumIncidenceAngle': None,
#     'maximumIncidenceAngle': None,
#     'incidenceAngleVariation': None,
#     'niirs': 5.6,
#     'verticalAccuracy': None,
#     'tagsAsString': ''}},
#   {'type': 'Feature',
#    'id': 'bb6b92a5d99696e9d66bdab4a59e3d24',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[41.90744887, -69.98398238],
#       [41.96204872, -69.9807811],
#       [42.01663211, -69.97756302],
#       [42.07367135, -69.97421164],
#       [42.12930807, -69.97094167],
#       [42.18538191, -69.96764666],
#       [42.24091369, -69.96438498],
#       [42.29744807, -69.96106225],
#       [42.34832243, -69.95807391],
#       [42.34884541, -69.98923594],
#       [42.34936917, -70.02039787],
#       [42.34989372, -70.0515597],
#       [42.35041905, -70.08272144],
#       [42.35094518, -70.11388308],
#       [42.35147212, -70.14504462],
#       [42.35199985, -70.17620607],
#       [42.3525284, -70.20736742],
#       [42.35305777, -70.23852867],
#       [42.35358795, -70.26968983],
#       [42.35411897, -70.3008509],
#       [42.35465081, -70.33201187],
#       [42.3551835, -70.36317274],
#       [42.35571703, -70.39433351],
#       [42.3562514, -70.42549419],
#       [42.35678664, -70.45665478],
#       [42.35732273, -70.48781527],
#       [42.35785969, -70.51897567],
#       [42.35839752, -70.55013597],
#       [42.35893622, -70.58129617],
#       [42.35947581, -70.61245629],
#       [42.36001629, -70.6436163],
#       [42.36055766, -70.67477623],
#       [42.36109994, -70.70593605],
#       [42.36164312, -70.73709579],
#       [42.36218721, -70.76825543],
#       [42.36273222, -70.79941497],
#       [42.36327816, -70.83057443],
#       [42.36382502, -70.86173378],
#       [42.36437283, -70.89289305],
#       [42.36492157, -70.92405222],
#       [42.36547127, -70.9552113],
#       [42.36602191, -70.98637028],
#       [42.36657352, -71.01752918],
#       [42.36657155, -71.01754394],
#       [42.36546055, -71.01760959],
#       [42.28628112, -71.02220656],
#       [42.20706541, -71.02676978],
#       [42.1278137, -71.03129921],
#       [42.04852624, -71.03579482],
#       [41.96920329, -71.0402566],
#       [41.88984512, -71.04468451],
#       [41.88977701, -71.04468337],
#       [41.88977562, -71.04447614],
#       [41.89033789, -71.01328674],
#       [41.89089747, -70.98209725],
#       [41.89145437, -70.95090766],
#       [41.89200859, -70.91971797],
#       [41.89256016, -70.88852819],
#       [41.89310908, -70.85733831],
#       [41.89365537, -70.82614833],
#       [41.89419903, -70.79495826],
#       [41.89474008, -70.7637681],
#       [41.89527853, -70.73257784],
#       [41.89581438, -70.70138748],
#       [41.89634766, -70.67019702],
#       [41.89687837, -70.63900647],
#       [41.89740653, -70.60781582],
#       [41.89793213, -70.57662508],
#       [41.8984552, -70.54543423],
#       [41.89897575, -70.51424329],
#       [41.89949378, -70.48305226],
#       [41.90000931, -70.45186112],
#       [41.90052235, -70.42066989],
#       [41.90103291, -70.38947857],
#       [41.90154099, -70.35828714],
#       [41.90204661, -70.32709562],
#       [41.90254978, -70.29590399],
#       [41.90305051, -70.26471228],
#       [41.90354881, -70.23352046],
#       [41.90404468, -70.20232854],
#       [41.90453815, -70.17113653],
#       [41.90502921, -70.13994442],
#       [41.90551789, -70.10875221],
#       [41.90600418, -70.0775599],
#       [41.9064881, -70.04636749],
#       [41.90696966, -70.01517499],
#       [41.90744887, -69.98398238]]]},
#    'geometry_name': 'geometry',
#    'properties': {'featureId': 'bb6b92a5d99696e9d66bdab4a59e3d24',
#     'acquisitionDate': '2023-01-28 06:25:12',
#     'acquisitionTime': 625,
#     'sensorType': '',
#     'source': 'WV03_VNIR',
#     'sourceUnit': 'Strip',
#     'productType': 'Pan Sharpened Natural Color',
#     'CE90Accuracy': None,
#     'RMSEAccuracy': None,
#     'cloudCover': 0,
#     'offNadirAngle': 29.738827,
#     'sunElevation': 31.428951,
#     'sunAzimuth': 51.587246,
#     'groundSampleDistance': 0.41,
#     'groundSampleDistanceUnit': 'Meter',
#     'dataLayer': 'daily_take',
#     'legacyDescription': 'AOI14_L2_WV3',
#     'outputMosaic': False,
#     'colorBandOrder': 'RGB',
#     'assetName': 'FINISHED',
#     'assetType': 'PRODUCT_GEOMETRY',
#     'legacyId': '10400100812DD200',
#     'factoryOrderNumber': '015585364-10',
#     'perPixelX': 0.41218724846839905,
#     'perPixelY': -0.41218724846839905,
#     'crsFromPixels': 'EPSG:32738',
#     'url': '',
#     'ageDays': 564,
#     'formattedDate': '2023-01-28',
#     'ingestDate': '2023-01-28 12:37:37',
#     'spatialAccuracy': '',
#     'earliestAcquisitionDate': '2023-01-28 06:25:12',
#     'latestAcquisitionDate': '2023-01-28 06:25:12',
#     'pixelsIngested': True,
#     'preciseGeometry': True,
#     'vendorName': '',
#     'vendorReference': '',
#     'companyName': 'DigitalGlobe',
#     'acquisitionType': '',
#     'orbitDirection': '',
#     'licenseType': '',
#     'isBrowse': False,
#     'isMirrored': False,
#     'isMultipleWKB': False,
#     'copyright': 'Image Copyright 2023 DigitalGlobe Inc',
#     'beamMode': '',
#     'polarisationMode': '',
#     'polarisationChannel': '',
#     'antennaLookDirection': '',
#     'minimumIncidenceAngle': None,
#     'maximumIncidenceAngle': None,
#     'incidenceAngleVariation': None,
#     'niirs': 5.3,
#     'verticalAccuracy': None,
#     'tagsAsString': ''}},
#   {'type': 'Feature',
#    'id': '730d3f7f63c582057b1c1cace278d79f',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[41.93611215, -69.98693423],
#       [41.98337923, -69.98700648],
#       [42.03064685, -69.98706618],
#       [42.07844936, -69.98713973],
#       [42.12625241, -69.98720045],
#       [42.17384195, -69.98727377],
#       [42.22143203, -69.98733437],
#       [42.26829868, -69.98740798],
#       [42.31516586, -69.98746926],
#       [42.31556384, -70.01865],
#       [42.31596223, -70.04983065],
#       [42.31636101, -70.08101119],
#       [42.3167602, -70.11219164],
#       [42.3171598, -70.143372],
#       [42.31755981, -70.17455226],
#       [42.31796023, -70.20573242],
#       [42.31836108, -70.23691249],
#       [42.31876234, -70.26809246],
#       [42.31916403, -70.29927233],
#       [42.31956615, -70.33045211],
#       [42.3199687, -70.3616318],
#       [42.32037168, -70.39281138],
#       [42.32077511, -70.42399088],
#       [42.32117897, -70.45517028],
#       [42.32158329, -70.48634958],
#       [42.32198805, -70.51752879],
#       [42.32239327, -70.5487079],
#       [42.32279895, -70.57988692],
#       [42.32320509, -70.61106585],
#       [42.32361169, -70.64224468],
#       [42.32401876, -70.67342341],
#       [42.3244263, -70.70460206],
#       [42.32483432, -70.7357806],
#       [42.32524282, -70.76695906],
#       [42.3256518, -70.79813742],
#       [42.32606128, -70.82931569],
#       [42.32647124, -70.86049386],
#       [42.3268817, -70.89167194],
#       [42.32729266, -70.92284993],
#       [42.32770412, -70.95402782],
#       [42.32811609, -70.98520562],
#       [42.32852857, -71.01638333],
#       [42.24750074, -71.01533385],
#       [42.16648227, -71.0142491],
#       [42.08547345, -71.01312909],
#       [42.00447459, -71.01197384],
#       [41.923486, -71.01078334],
#       [41.92390241, -70.97975912],
#       [41.92431661, -70.94873481],
#       [41.92472862, -70.9177104],
#       [41.92513845, -70.8866859],
#       [41.9255461, -70.8556613],
#       [41.92595158, -70.82463661],
#       [41.9263549, -70.79361183],
#       [41.92675608, -70.76258695],
#       [41.92715511, -70.73156198],
#       [41.92755201, -70.70053692],
#       [41.92794679, -70.66951176],
#       [41.92833946, -70.63848651],
#       [41.92873002, -70.60746116],
#       [41.92911849, -70.57643572],
#       [41.92950487, -70.54541018],
#       [41.92988917, -70.51438455],
#       [41.93027139, -70.48335883],
#       [41.93065156, -70.45233301],
#       [41.93102967, -70.42130709],
#       [41.93140574, -70.39028108],
#       [41.93177977, -70.35925497],
#       [41.93215177, -70.32822877],
#       [41.93252175, -70.29720248],
#       [41.93288971, -70.26617608],
#       [41.93325568, -70.23514959],
#       [41.93361964, -70.20412301],
#       [41.93398162, -70.17309633],
#       [41.93434161, -70.14206955],
#       [41.93469964, -70.11104268],
#       [41.93505569, -70.08001571],
#       [41.9354098, -70.04898865],
#       [41.93576195, -70.01796149],
#       [41.93611215, -69.98693423]]]},
#    'geometry_name': 'geometry',
#    'properties': {'featureId': '730d3f7f63c582057b1c1cace278d79f',
#     'acquisitionDate': '2023-01-28 06:23:49',
#     'acquisitionTime': 623,
#     'sensorType': '',
#     'source': 'WV03_VNIR',
#     'sourceUnit': 'Strip',
#     'productType': 'Pan Sharpened Natural Color',
#     'CE90Accuracy': None,
#     'RMSEAccuracy': None,
#     'cloudCover': 0,
#     'offNadirAngle': 20.657362,
#     'sunElevation': 31.337265,
#     'sunAzimuth': 51.954796,
#     'groundSampleDistance': 0.36,
#     'groundSampleDistanceUnit': 'Meter',
#     'dataLayer': 'daily_take',
#     'legacyDescription': 'AOI14_L2_WV3',
#     'outputMosaic': False,
#     'colorBandOrder': 'RGB',
#     'assetName': 'FINISHED',
#     'assetType': 'PRODUCT_GEOMETRY',
#     'legacyId': '1040010082CBCF00',
#     'factoryOrderNumber': '015585344-10',
#     'perPixelX': 0.3570871353149414,
#     'perPixelY': -0.3570871353149414,
#     'crsFromPixels': 'EPSG:32738',
#     'url': '',
#     'ageDays': 564,
#     'formattedDate': '2023-01-28',
#     'ingestDate': '2023-01-28 11:54:30',
#     'spatialAccuracy': '',
#     'earliestAcquisitionDate': '2023-01-28 06:23:50',
#     'latestAcquisitionDate': '2023-01-28 06:23:50',
#     'pixelsIngested': True,
#     'preciseGeometry': True,
#     'vendorName': '',
#     'vendorReference': '',
#     'companyName': 'DigitalGlobe',
#     'acquisitionType': '',
#     'orbitDirection': '',
#     'licenseType': '',
#     'isBrowse': False,
#     'isMirrored': False,
#     'isMultipleWKB': False,
#     'copyright': 'Image Copyright 2023 DigitalGlobe Inc',
#     'beamMode': '',
#     'polarisationMode': '',
#     'polarisationChannel': '',
#     'antennaLookDirection': '',
#     'minimumIncidenceAngle': None,
#     'maximumIncidenceAngle': None,
#     'incidenceAngleVariation': None,
#     'niirs': 5.5,
#     'verticalAccuracy': None,
#     'tagsAsString': ''}}],
#  'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4326'}}}

# %% [markdown]
# ### Create a GeoDataFrame from query results

# %%
df = pd.DataFrame()

for i, record in enumerate(r['features']):
    df.loc[i, 'id'] = record['id']
    df.loc[i, 'aoi_id'] = aoi_id
    df.loc[i, 'legacy_id'] = record['properties']['legacyId']
    df.loc[i, 'factory_order_number'] = record['properties']['factoryOrderNumber']
    df.loc[i, 'acquisition_date'] = record['properties']['acquisitionDate']
    df.loc[i, 'source'] = record['properties']['source']
    df.loc[i, 'source_unit'] = record['properties']['sourceUnit']
    df.loc[i, 'product_type'] = record['properties']['productType']
    df.loc[i, 'cloud_cover'] = record['properties']['cloudCover']
    df.loc[i, 'off_nadir_angle'] = record['properties']['offNadirAngle']
    df.loc[i, 'sun_elevation'] = record['properties']['sunElevation']
    df.loc[i, 'sun_azimuth'] = record['properties']['sunAzimuth']
    df.loc[i, 'ground_sample_distance'] = record['properties']['groundSampleDistance']
    df.loc[i, 'data_layer'] = record['properties']['dataLayer']
    df.loc[i, 'legacy_description'] = record['properties']['legacyDescription']
    df.loc[i, 'color_band_order'] = record['properties']['colorBandOrder']
    df.loc[i, 'asset_name'] = record['properties']['assetName']
    df.loc[i, 'per_pixel_x'] = record['properties']['perPixelX']
    df.loc[i, 'per_pixel_y'] = record['properties']['perPixelY']
    df.loc[i, 'crs_from_pixels'] = record['properties']['crsFromPixels']
    df.loc[i, 'age_days'] = record['properties']['ageDays']
    df.loc[i, 'ingest_date'] = record['properties']['ingestDate']
    df.loc[i, 'company_name'] = record['properties']['companyName']
    df.loc[i, 'copyright'] = record['properties']['copyright']
    df.loc[i, 'niirs'] = record['properties']['niirs']
    df.loc[i, 'geometry'] = Polygon([list(reversed(point)) for point in record['geometry']['coordinates'][0]])
    # df.loc[i, 'geometry'] = Polygon(record['geometry']['coordinates'][0])
gdf = gpd.GeoDataFrame(df, geometry='geometry')
# gdf = gdf.set_geometry("geometry").set_crs(df['crs_from_pixels'][0])
# gdf = gdf.to_crs(4326)
gdf = gdf.set_crs(4326)
gdf
# Out:
#                                  id aoi_id         legacy_id  \
# 0  574efe4bff88148b10f9043c889ff154      6  1040010089677300
# 1  bb6b92a5d99696e9d66bdab4a59e3d24      6  10400100812DD200
# 2  730d3f7f63c582057b1c1cace278d79f      6  1040010082CBCF00
#
#   factory_order_number     acquisition_date     source source_unit  \
# 0         016024927-10  2023-10-01 06:02:38  WV03_VNIR       Strip
# 1         015585364-10  2023-01-28 06:25:12  WV03_VNIR       Strip
# 2         015585344-10  2023-01-28 06:23:49  WV03_VNIR       Strip
#
#                   product_type  cloud_cover  off_nadir_angle  ...  asset_name  \
# 0  Pan Sharpened Natural Color          0.0         7.132186  ...    FINISHED
# 1  Pan Sharpened Natural Color          0.0        29.738827  ...    FINISHED
# 2  Pan Sharpened Natural Color          0.0        20.657362  ...    FINISHED
#
#    per_pixel_x  per_pixel_y crs_from_pixels age_days          ingest_date  \
# 0     0.322669    -0.322669      EPSG:32738    318.0  2023-10-01 12:34:43
# 1     0.412187    -0.412187      EPSG:32738    564.0  2023-01-28 12:37:37
# 2     0.357087    -0.357087      EPSG:32738    564.0  2023-01-28 11:54:30
#
#    company_name                              copyright  niirs  \
# 0  DigitalGlobe  Image Copyright 2023 DigitalGlobe Inc    5.6
# 1  DigitalGlobe  Image Copyright 2023 DigitalGlobe Inc    5.3
# 2  DigitalGlobe  Image Copyright 2023 DigitalGlobe Inc    5.5
#
#                                             geometry
# 0  POLYGON ((-69.98922 41.98936, -69.98883 42.078...
# 1  POLYGON ((-69.98398 41.90745, -69.98078 41.962...
# 2  POLYGON ((-69.98693 41.93611, -69.98701 41.983...
#
# [3 rows x 26 columns]

# %%
gdf.shape
# Out:
# (3, 26)

# %% [markdown]
# ### Drop table
# This is for demonstration purposes

# %%
conn = sqlite3.connect(db)
conn.enable_load_extension(True)
conn.execute("SELECT load_extension('mod_spatialite')")

c = conn.cursor()
c.execute('''DROP TABLE IF EXISTS gegd''')
conn.commit()
conn.close()

# %% [markdown]
# ### Create `gedg` table

# %%
conn = sqlite3.connect(db)
conn.enable_load_extension(True)
conn.execute("SELECT load_extension('mod_spatialite')")
# conn.execute("")

c = conn.cursor()

c.execute('''
    CREATE TABLE IF NOT EXISTS gegd(
        id VARCHAR(32) PRIMARY KEY,
        aoi_id VARCHAR(4),
        legacy_id VARCHAR(16),
        factory_order_number VARCHAR(12),
        acquisition_date SMALLDATETIME,
        source VARCHAR(9),
        source_unit VARCHAR(5),
        product_type VARCHAR(36),
        cloud_cover NUMERIC(3,2),
        off_nadir_angle NUMERIC(2, 3),
        sun_elevation NUMERIC(3, 3),
        sun_azimuth NUMERIC(3, 3),
        ground_sample_distance NUMERIC(2, 2),
        data_layer VARCHAR(10),
        legacy_description VARCHAR(12),
        color_band_order VARCHAR(3),
        asset_name VARCHAR(8),
        per_pixel_x NUMERIC(2, 2),
        per_pixel_y NUMERIC(2, 2),
        crs_from_pixels VARCHAR(10),
        age_days NUMERIC(4, 1),
        ingest_date SMALLDATETIME,
        company_name VARCHAR(12),
        copyright VARCHAR(37),
        niirs NUMERIC(1, 1),
        geometry POLYGON,
        FOREIGN KEY (aoi_id)
            REFERENCES aoi(id)
    )
''')

conn.commit()
conn.close()

# %% [markdown]
# ### Insert Maxar Geospatial Platform IDs into `mgp` table

# %%
conn = sqlite3.connect(db)
conn.enable_load_extension(True)
conn.execute("SELECT load_extension('mod_spatialite')")

c = conn.cursor()

for i, row in gdf.iterrows():
    try:
        insert_gedg(c, row['id'])
    except Exception as e:
        print("Exception: {} was raised for ID {}".format(e, row['id']))
print("Done inserting Imagery IDs into table!")
conn.commit()
conn.close()
# Out:
# Done inserting Imagery IDs into table!

# %% [markdown]
# ### Update `mgp` records from Maxar Geospatial Platform results

# %%
columns = gdf.columns[1:]
for i, row in gdf.iterrows():
    iid = row['id']
    print("Updating information for Imagery ID: {}".format(iid))
    for column in columns:
        database_activity(db, iid, column, row[column])
# Out:
# Updating information for Imagery ID: 574efe4bff88148b10f9043c889ff154
# Updating information for Imagery ID: bb6b92a5d99696e9d66bdab4a59e3d24
# Updating information for Imagery ID: 730d3f7f63c582057b1c1cace278d79f

# %% [markdown]
# ### Select newly inserted AOIs, make a GeoDataFrame for validation

# %%
conn = sqlite3.connect(db)
conn.enable_load_extension(True)
conn.execute("SELECT load_extension('mod_spatialite')")

columns_list = list(gdf.columns[:-1])
columns_str = ', '.join(columns_list)
sql_string = "SELECT {}, AsText(geometry) FROM gegd WHERE id IS NOT NULL".format(columns_str)

df = pd.read_sql_query(sql_string, conn)
df = df.rename(columns={'AsText(geometry)': 'geometry'}, errors='raise')
df['geometry'] = shapely.wkt.loads(df['geometry'])
gdf = gpd.GeoDataFrame(df, geometry='geometry')

conn.commit()
conn.close()

gdf.head()
# Out:
#                                  id aoi_id         legacy_id  \
# 0  574efe4bff88148b10f9043c889ff154      6  1040010089677300
# 1  bb6b92a5d99696e9d66bdab4a59e3d24      6  10400100812DD200
# 2  730d3f7f63c582057b1c1cace278d79f      6  1040010082CBCF00
#
#   factory_order_number     acquisition_date     source source_unit  \
# 0         016024927-10  2023-10-01 06:02:38  WV03_VNIR       Strip
# 1         015585364-10  2023-01-28 06:25:12  WV03_VNIR       Strip
# 2         015585344-10  2023-01-28 06:23:49  WV03_VNIR       Strip
#
#                   product_type  cloud_cover  off_nadir_angle  ...  asset_name  \
# 0  Pan Sharpened Natural Color            0         7.132186  ...    FINISHED
# 1  Pan Sharpened Natural Color            0        29.738827  ...    FINISHED
# 2  Pan Sharpened Natural Color            0        20.657362  ...    FINISHED
#
#    per_pixel_x  per_pixel_y crs_from_pixels age_days          ingest_date  \
# 0     0.322669    -0.322669      EPSG:32738      318  2023-10-01 12:34:43
# 1     0.412187    -0.412187      EPSG:32738      564  2023-01-28 12:37:37
# 2     0.357087    -0.357087      EPSG:32738      564  2023-01-28 11:54:30
#
#    company_name                              copyright  niirs  \
# 0  DigitalGlobe  Image Copyright 2023 DigitalGlobe Inc    5.6
# 1  DigitalGlobe  Image Copyright 2023 DigitalGlobe Inc    5.3
# 2  DigitalGlobe  Image Copyright 2023 DigitalGlobe Inc    5.5
#
#                                             geometry
# 0  POLYGON ((-69.98922 41.98936, -69.98883 42.078...
# 1  POLYGON ((-69.98398 41.90745, -69.98078 41.962...
# 2  POLYGON ((-69.98693 41.93611, -69.98701 41.983...
#
# [3 rows x 26 columns]

# %%
# Note that the GDF shape matches that from the above
gdf.shape
# Out:
# (3, 26)

# %% [markdown]
# ### Plot Areas of Interest on an Interactive Map

# %%
def style_function(hex_value):
    return {'color': hex_value, 'fillOpacity': 0}

# Add OpenStreetMap as a basemap
map = folium.Map()
folium.TileLayer('openstreetmap').add_to(map)

# Create a GeoJson layer from the response_geojson and add it to the map
folium.GeoJson(
    gdf['geometry'].to_json(),
    style_function = lambda x: style_function('#0000FF')
).add_to(map)

folium.GeoJson(
    gdf_aoi['geometry'].to_json(),
    style_function = lambda x: style_function('#FF0000')
).add_to(map)

# Zoom to collected images
map.fit_bounds(map.get_bounds(), padding=(100, 100))

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_59996dbacbf25e4c792dd6f08ebcc96d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_59996dbacbf25e4c792dd6f08ebcc96d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_59996dbacbf25e4c792dd6f08ebcc96d = L.map(
#                 &quot;map_59996dbacbf25e4c792dd6f08ebcc96d&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3a93eeb2fbfd9dabf35f3cb61c022093 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3a93eeb2fbfd9dabf35f3cb61c022093.addTo(map_59996dbacbf25e4c792dd6f08ebcc96d);
#
#
#             var tile_layer_42746cf5912bcbb96915cba985df2faa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_42746cf5912bcbb96915cba985df2faa.addTo(map_59996dbacbf25e4c792dd6f08ebcc96d);
#
#
#         function geo_json_f868b355056e2edd096cfe97eeb344db_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#0000FF&quot;, &quot;fillOpacity&quot;: 0};
#             }
#         }
#
#         function geo_json_f868b355056e2edd096cfe97eeb344db_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_f868b355056e2edd096cfe97eeb344db = L.geoJson(null, {
#                 onEachFeature: geo_json_f868b355056e2edd096cfe97eeb344db_onEachFeature,
#
#                 style: geo_json_f868b355056e2edd096cfe97eeb344db_styler,
#         });
#
#         function geo_json_f868b355056e2edd096cfe97eeb344db_add (data) {
#             geo_json_f868b355056e2edd096cfe97eeb344db
#                 .addData(data);
#         }
#             geo_json_f868b355056e2edd096cfe97eeb344db_add({&quot;bbox&quot;: [-71.044685, 41.889776, -69.958074, 42.366574], &quot;features&quot;: [{&quot;bbox&quot;: [-71.011281, 41.98413, -69.987642, 42.358555], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-69.989218, 41.989361], [-69.988828, 42.078879], [-69.988636, 42.124446], [-69.988433, 42.170013], [-69.98824, 42.215863], [-69.988035, 42.261713], [-69.987642, 42.352498], [-70.018656, 42.352685], [-70.04967, 42.352872], [-70.080683, 42.353059], [-70.111697, 42.353245], [-70.14271, 42.353431], [-70.173723, 42.353617], [-70.204736, 42.353803], [-70.235749, 42.353988], [-70.266762, 42.354173], [-70.297775, 42.354358], [-70.328788, 42.354543], [-70.359801, 42.354728], [-70.390813, 42.354912], [-70.421826, 42.355096], [-70.452838, 42.35528], [-70.48385, 42.355464], [-70.514863, 42.355648], [-70.545875, 42.355831], [-70.576887, 42.356014], [-70.607899, 42.356197], [-70.638911, 42.35638], [-70.669922, 42.356562], [-70.700934, 42.356744], [-70.731945, 42.356926], [-70.762957, 42.357108], [-70.793968, 42.35729], [-70.824979, 42.357471], [-70.855991, 42.357652], [-70.887002, 42.357833], [-70.918013, 42.358014], [-70.949024, 42.358195], [-70.980034, 42.358375], [-71.011045, 42.358555], [-71.011074, 42.344697], [-71.011186, 42.254555], [-71.011255, 42.164413], [-71.011281, 42.074271], [-71.011262, 41.98413], [-70.980293, 41.984311], [-70.949323, 41.98449], [-70.918353, 41.984668], [-70.887384, 41.984844], [-70.856414, 41.985019], [-70.825444, 41.985193], [-70.794474, 41.985365], [-70.763503, 41.985536], [-70.732533, 41.985705], [-70.701563, 41.985873], [-70.670592, 41.98604], [-70.639622, 41.986205], [-70.608651, 41.986369], [-70.57768, 41.986531], [-70.546709, 41.986692], [-70.515738, 41.986852], [-70.484767, 41.98701], [-70.453796, 41.987167], [-70.422825, 41.987322], [-70.391854, 41.987477], [-70.360882, 41.987629], [-70.329911, 41.987781], [-70.298939, 41.987931], [-70.267967, 41.98808], [-70.236996, 41.988228], [-70.206024, 41.988374], [-70.175052, 41.988519], [-70.14408, 41.988662], [-70.113108, 41.988805], [-70.082135, 41.988946], [-70.051163, 41.989085], [-70.020191, 41.989224], [-69.989218, 41.989361]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-71.044685, 41.889776, -69.958074, 42.366574], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-69.983982, 41.907449], [-69.980781, 41.962049], [-69.977563, 42.016632], [-69.974212, 42.073671], [-69.970942, 42.129308], [-69.967647, 42.185382], [-69.964385, 42.240

# %% [markdown]
# # End
