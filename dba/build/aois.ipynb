# %% [markdown]
# # Build (AOIs)
# This is the initalizing notebook for building a spatially enabled SQLite database supporting the GAIA program. The notebook identifies downloaded Keyhole Mark-up Language (KMLs) files, denoting Areas of Interest (AOIs), converts them to GeoJSON files, builds a GeoPandas GeoDataFrame, then commits this to the SQLite Database.
#
# ### Import libraries

# %%
# Basic stack
import os
import shutil
from glob import glob

# Web stack
import json

# Database stack
import sqlite3

# Data Science stack
import pyproj
from pyproj import CRS
from pyproj.aoi import AreaOfInterest
from pyproj.database import query_utm_crs_info
import utm
import pandas as pd
import geopandas as gpd
import shapely
from shapely import to_geojson
from shapely.ops import transform
from shapely.geometry import Polygon
from fiona.drvsupport import supported_drivers
import folium

# Custom stack
import sys; sys.path.append("../../")
from EE import security, search

# %% [markdown]
# ### User defined variables

# %%
transfer_aois = "C:/gis/gaia/transfer/aois"
dir_kml = "C:/gis/gaia/data/kmls"
db = "C:/gis/gaia/data/databases/gaia.db"

# %% [markdown]
# ### User defined functions

# %%
def select_data(c, columns):
    """ Selects all data from the `aois` table for review

        C - A cursor
        COLUMNS - Columns of interest
    """
    columns = ', '.join(columns)
    sql_string = f"SELECT {columns}, AsText(geom) FROM aois"
    c.execute(sql_string)
    return c.fetchall()

def update_aoi(c, idd, name, utm, sqkm, geom):
    """ Insert/update the `aois` SQLite Data Table with a new Area of Interest.

        C - A cursor
        AOI ID - The AOI ID
        NAME - The location name
        UTM - The UTM Zone as an EPSG code
        SQKM - Square kilometers
        GEOM - The area of interest's geometry
    """
    sql_string = (f"INSERT INTO aoi(aid, name, utm, sqkm, geom) \n"
                     f"VALUES ({idd}, \"{name}\", \"{utm}\", {sqkm}, ST_GeomFromText(\"{geom}\", 4326))")
    c.execute(sql_string)

def utm_and_area(aoi):
    """ Determines the UTM Zone, as an EPSG code, of an Area of Interest
            as well as culates the area, in square kilometers, of this
            Area of Interest.

        AOI - Area of Interest as a Shapely Polygon
    """
    minx, miny, maxx, maxy = aoi.bounds
    
    utm_crs_list = query_utm_crs_info(
        datum_name = "WGS 84",
        area_of_interest=AreaOfInterest(
            west_lon_degree = minx,
            south_lat_degree = miny,
            east_lon_degree = maxx,
            north_lat_degree = maxy,
        ),
    )

    if len(utm_crs_list) == 1:
        print("One zone, {}, was identified and will be used for calculations.".format(utm_crs_list[0].name))
    else:
        print("Multiple zones were identified. {} will be used for calculations.".format(utm_crs_list[0].name))
        alt_utms = [utm_crs.name for utm_crs in utm_crs_list][1:]
        print("\tOther options were: {}".format(alt_utms))
    
    utm_crs = CRS.from_epsg(utm_crs_list[0].code)
    proj_wgs2utm = pyproj.Transformer.from_crs(pyproj.CRS('EPSG:4326'), utm_crs, always_xy=True).transform
    sqkm = transform(proj_wgs2utm, aoi).area / 1_000_000
    return utm_crs, sqkm

def geojson_to_row(geojson):
    """ Creates a GeoDataFrame from a GeoJSON file then adds columns for
            the AOI ID, location name, UTM Zone (as an EPSG code), and
            area in square kilometers.

        Is dependent on the UTM_AND_AREA function above.

        GEOJSON - A GeoJSON file
    """
    try:
        gdf = gpd.read_file(geojson, crs='EPSG:4326')
        root_name = geojson.split('/')[-1]
        gdf['id'] = root_name.split('.')[0].split('-')[0]
        gdf['name'] = root_name.split('.')[0].split('-')[1]
        utm_crs, sqkm = utm_and_area(gdf['geometry'][0])
        gdf['utm'] = utm_crs
        gdf['sqkm'] = round(sqkm, 2)
        return gdf
    except Exception as e:
        print("Failed on {} due to: {}".format(geojson, e))
        pass

def kml_to_geojson(kml, out_dir):
    """ Converts a KML file to GeoJSON file.

        KML - KML file
        OUT DIR - Output directory
    """
    supported_drivers['KML'] = 'rw'

    kml_name = kml.split('\\')[-1]
    gdf = gpd.read_file(kml, driver='KML')
    if len(gdf["geometry"]) == 1:
        kml_shape = to_geojson(gdf['geometry'][0])

        root_name = kml_name.split('.')[0]
        geojson_file = "{}/{}.geojson".format(out_dir, root_name)
        with open(geojson_file, "w") as f:
            f.write(kml_shape)
            f.close()
        
        with open(geojson_file, "r") as f:
            aoi = json.loads(f.read())
            f.close()

        return geojson_file
            
    elif len(gdf["geometry"]) > 1:
        print("More than one geometry found in your {} KML. Passing...".format(kml_name))
        pass

# %% [markdown]
# ### Identify, move Areas of Interest (AOIs) as KMLs

# %%
aoi_kmls = glob(transfer_aois + "/*.kml")
for aoi_kml in aoi_kmls:
    aoi_name = aoi_kml.split('\\')[-1]
    kml_aoi = "{}/{}".format(dir_kml, aoi_name)
    shutil.move(aoi_kml, kml_aoi)

# %% [markdown]
# ### Provide some feedback to the user on what was moved

# %%
transfer_files = glob(transfer_aois + "/*.*")
kml_count = len(aoi_kmls) - len(transfer_files)
print("{} KMLs were moved. You still have {} files in your transfer aois directory".format(kml_count, len(transfer_files)))
# Out:
# -25 KMLs were moved. You still have 25 files in your transfer aois directory

# %% [markdown]
# ### Convert AOI KMLs to GeoJSON files

# %%
aoi_kmls = glob(dir_kml + "/*.kml")
dir_geojson = "C:/gis/gaia/data/geojson"
aoi_geojsons = [kml_to_geojson(aoi_kml, dir_geojson) for aoi_kml in aoi_kmls]
# Out:
# More than one geometry found in your 0135-RemoteSensingSI-NWFSC-WestofSanJuans.kml KML. Passing...

# %% [markdown]
# ### Read GeoJSONs into GeoDataFrame

# %%
gdf = pd.concat([geojson_to_row(aoi_geojson) for aoi_geojson in aoi_geojsons], ignore_index=True)
corrected_columns = ['id', 'name', 'utm', 'sqkm', 'geometry']
gdf = gdf[corrected_columns]
gdf = gdf.rename(columns = {'id': 'aid'})
gdf.head()
# Out:
# One zone, WGS 84 / UTM zone 5N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 5N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 5N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 5N, was identified and will be used for calculations.
# Multiple zones were identified. WGS 84 / UTM zone 5N will be used for calculations.
# 	Other options were: ['WGS 84 / UTM zone 6N']
# One zone, WGS 84 / UTM zone 19N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 19N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 19N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 19N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 19N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 19N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 19N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 19N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 19N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 20N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 19N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 19N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 19N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 18N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 22N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 19N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 19N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 4N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 5N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 5N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 3N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 52S, was identified and will be used for calculations.
# Multiple zones were identified. WGS 84 / UTM zone 21S will be used for calculations.
# 	Other options were: ['WGS 84 / UTM zone 22S']
# Multiple zones were identified. WGS 84 / UTM zone 4N will be used for calculations.
# 	Other options were: ['WGS 84 / UTM zone 5N']
# One zone, WGS 84 / UTM zone 5N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 9N, was identified and will be used for calculations.
# Multiple zones were identified. WGS 84 / UTM zone 9N will be used for calculations.
# 	Other options were: ['WGS 84 / UTM zone 10N']
# One zone, WGS 84 / UTM zone 4N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 19N, was identified and will be used for calculations.
# Multiple zones were identified. WGS 84 / UTM zone 49S will be used for calculations.
# 	Other options were: ['WGS 84 / UTM zone 50S']
# One zone, WGS 84 / UTM zone 10N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 19N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 2N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 2N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 19N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 10N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 10N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 36S, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 36S, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 10N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 34S, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 19N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 3N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 3N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 20N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 23N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 19N, was identified and will be used for calculations.
# Failed on None due to: None: No such file or directory
# One zone, WGS 84 / UTM zone 3N, was identified and will be used for calculations.
# One zone, WGS 84 / UTM zone 16N, was identified and will be used for calculations.
# Failed on None due to: None: No such file or directory
# One zone, WGS 84 / UTM zone 14N, was identified and will be used for calculations.
#     aid           name         utm     sqkm  \
# 0  0001          Kenai  EPSG:32605   416.53
# 1  0002  Kalgin Island  EPSG:32605   884.65
# 2  0003    Trading Bay  EPSG:32605   529.37
# 3  0004        Tuxedni  EPSG:32605   438.72
# 4  0005       Upper CI  EPSG:32605  1871.28
#
#                                             geometry
# 0  POLYGON ((-151.59303 60.32094, -151.43153 60.6...
# 1  POLYGON ((-151.73795 60.71243, -151.69676 60.5...
# 2  POLYGON ((-151.34361 61.01015, -151.22669 60.9...
# 3  POLYGON ((-152.60081 60.02992, -152.59393 60.0...
# 4  POLYGON ((-150.67303 60.95571, -151.00321 61.1...

# %%
gdf.shape
# Out:
# (55, 5)

# %%
gdf.head(55)
# Out:
#      aid                                 name         utm      sqkm  \
# 0   0001                                Kenai  EPSG:32605    416.53
# 1   0002                        Kalgin Island  EPSG:32605    884.65
# 2   0003                          Trading Bay  EPSG:32605    529.37
# 3   0004                              Tuxedni  EPSG:32605    438.72
# 4   0005                             Upper CI  EPSG:32605   1871.28
# 5   0006                         Cape Cod Bay  EPSG:32619   1347.04
# 6   0007                   Cape Cod Bay north  EPSG:32619   1291.27
# 7   0008                    North of Cape Cod  EPSG:32619   2145.21
# 8   0009                     East of Cape Cod  EPSG:32619    722.59
# 9   0010            East of Cape Cod, Monomoy  EPSG:32619   1396.58
# 10  0011                Southeast of Cape Cod  EPSG:32619   1350.75
# 11  0012                     Nantucket Shoals  EPSG:32619   2322.59
# 12  0013               Nantucket Shoals south  EPSG:32619   1018.12
# 13  0014               Nantucket Shoals north  EPSG:32619    746.66
# 14  0015                  Gulf of St Lawrence  EPSG:32620   1719.80
# 15  0016            Great South Channel north  EPSG:32619   1420.12
# 16  0017              Great South Channel mid  EPSG:32619   1445.13
# 17  0018            Great South Channel south  EPSG:32619   2253.24
# 18  0019                 SE Atlantic City, NJ  EPSG:32618   5474.53
# 19  0020          Bonavista Bay, Newfoundland  EPSG:32622   2392.85
# 20  0021  Northeast Channel, S of Nova Scotia  EPSG:32619   2396.29
# 21  0022                        Hudson Canyon  EPSG:32619   2392.17
# 22  0023                          Bristol Bay  EPSG:32604    963.75
# 23  0024                        Kodiak Island  EPSG:32605    912.58
# 24  0025                      Sitkinak Island  EPSG:32605    821.85
# 25  0026                        Unimak Island  EPSG:32603    962.16
# 26  0027                    Head of the Bight  EPSG:32752   2865.84
# 27  0028                              Uruguay  EPSG:32721  14621.37
# 28  0029                     Barrow, AK north  EPSG:32604   2378.96
# 29  0030                     Barrow, AK south  EPSG:32605   2415.97
# 30  0031                Northwest Territories  EPSG:32609   2211.55
# 31  0032           Northwest Territories east  EPSG:32609   2233.87
# 32  0033                               Hawaii  EPSG:32604   1627.82
# 33  0034                      Jeffrey_s Ledge  EPSG:32619   1629.79
# 34  0035                    Western Australia  EPSG:32749  15320.91
# 35  0036                      Point Lobos, CA  EPSG:32610     99.68
# 36  0037                      Muskegat Island  EPSG:32619      2.56
# 37  0038                     Lisianski Island  EPSG:32602      3.31
# 38  0039                          Kauo Island  EPSG:32602    851.83
# 39  0040                    South of Cape Cod  EPSG:32619    722.65
# 40  0041                           Bodega Bay  EPSG:32610   2138.34
# 41  0042                         Halfmoon Bay  EPSG:32610   2224.76
# 42  0043                      Mozambique west  EPSG:32736   2376.33
# 43  0044                      Mozambique east  EPSG:32736   2375.45
# 44  0045                         Monterey Bay  EPSG:32610   2333.70
# 45  0046                         South Africa  EPSG:32734   2043.24
# 46  0047                  Great South Channel  EPSG:32619   1479.64
# 47  0048                                 Nome  EPSG:32603   1721.56
# 48  0049                          Rocky Point  EPSG:32603    833.50
# 49  0050                        Gaspe, Canada  EPSG:32620   1054.42
# 50  0067                         Labrador Sea  EPSG:32623   1547.90
# 51  0124               Nantucket Shoals Final  EPSG:32619   2299.30
# 52  0132                      RemoteSensingSI  EPSG:32603    829.55
# 53  0133                      RemoteSensingSI  EPSG:32616    696.10
# 54  0136                RicesWhaleBox_700sqkm  EPSG:32614    690.90
#
#                                              geometry
# 0   POLYGON ((-151.59303 60.32094, -151.43153 60.6...
# 1   POLYGON ((-151.73795 60.71243, -151.69676 60.5...
# 2   POLYGON ((-151.34361 61.01015, -151.22669 60.9...
# 3   POLYGON ((-152.60081 60.02992, -152.59393 60.0...
# 4   POLYGON ((-150.67303 60.95571, -151.00321 61.1...
# 5   POLYGON ((-70.11938 42.10724, -70.52386 42.109...
# 6   POLYGON ((-70.62919 42.10035, -70.55071 41.965...
# 7   POLYGON ((-70.09225 42.16102, -70.02663 42.475...
# 8   POLYGON ((-69.93751 41.86854, -69.93751 41.605...
# 9   POLYGON ((-69.93951 41.55669, -69.31993 41.534...
# 10  POLYGON ((-69.26060 40.62189, -69.26060 40.298...
# 11  POLYGON ((-70.23455 40.91594, -69.66167 40.917...
# 12  POLYGON ((-70.23662 40.90184, -70.20192 40.662...
# 13  POLYGON ((-69.80088 40.89945, -69.84139 41.086...
# 14  POLYGON ((-64.19297 47.75844, -63.62336 47.696...
# 15  POLYGON ((-68.99833 42.01414, -68.99906 41.732...
# 16  POLYGON ((-68.99906 41.73227, -68.99830 41.448...
# 17  POLYGON ((-69.43333 40.84258, -68.93833 40.831...
# 18  POLYGON ((-74.60098 39.40608, -73.74260 39.406...
# 19  POLYGON ((-53.45244 48.88669, -52.79451 48.887...
# 20  POLYGON ((-66.60326 42.50348, -66.01748 42.504...
# 21  POLYGON ((-70.78951 39.91909, -70.21663 39.920...
# 22  POLYGON ((-160.61673 57.44234, -160.88833 57.6...
# 23  POLYGON ((-152.71714 57.06081, -152.40833 57.0...
# 24  POLYGON ((-154.51611 56.16262, -154.17640 56.1...
# 25  POLYGON ((-165.09358 54.54462, -165.35274 54.7...
# 26  POLYGON ((131.15094 -31.44265, 130.80144 -31.6...
# 27  POLYGON ((-53.33624 -33.78460, -52.76965 -33.9...
# 28  POLYGON ((-156.55236 71.62711, -156.52165 71.2...
# 29  POLYGON ((-155.40692 71.27864, -155.96682 71.2...
# 30  POLYGON ((-128.07209 70.57762, -127.27642 70.2...
# 31  POLYGON ((-126.42021 70.07760, -125.75998 70.5...
# 32  POLYGON ((-156.74029 20.67467, -156.35050 20.6...
# 33  POLYGON ((-69.88727 42.83980, -69.85934 43.203...
# 34  POLYGON ((113.11485 -23.05537, 114.10817 -23.1...
# 35  POLYGON ((-122.01418 36.48073, -121.99161 36.3...
# 36  POLYGON ((-70.28769 41.32849, -70.31164 41.328...
# 37  POLYGON ((-173.97382 26.07311, -173.97309 26.0...
# 38  POLYGON ((-171.87711 25.90404, -171.58118 25.8...
# 39  POLYGON ((-70.50680 40.61821, -70.50680 40.348...
# 40  POLYGON ((-123.07281 38.29984, -123.38193 38.2...
# 41  POLYGON ((-122.65190 37.77039, -122.86628 37.7...
# 42  POLYGON ((31.30000 -30.07000, 31.30000 -29.700...
# 43  POLYGON ((32.10000 -30.07000, 32.10000 -29.700...
# 44  POLYGON ((-121.89988 36.99251, -122.26243 37.0...
# 45  POLYGON ((20.02768 -34.77263, 20.09772 -34.862...
# 46  POLYGON ((-69.40847 41.19437, -68.80828 41.170...
# 47  POLYGON ((-166.03552 64.57548, -165.20987 64.5...
# 48  POLYGON ((-163.03515 64.42269, -163.15519 64.2...
# 49  POLYGON ((-64.02217 48.51936, -63.47581 48.516...
# 50  POLYGON ((-45.04169 54.87613, -44.44689 54.812...
# 51  POLYGON ((-70.27129 40.65716, -69.71293 40.646...
# 52  POLYGON ((-166.35000 23.90000, -166.35000 23.6...
# 53  POLYGON ((-86.03490 28.91191, -86.24148 29.101...
# 54  POLYGON ((-96.52632 27.01906, -96.33925 26.920...

# %% [markdown]
# ### Drop table
# This is for demonstration purposes

# %%
conn = sqlite3.connect(db)
conn.enable_load_extension(True)
conn.execute("SELECT load_extension('mod_spatialite')")

c = conn.cursor()
c.execute('''DROP TABLE IF EXISTS aois''')
conn.commit()
conn.close()

# %% [markdown]
# ### Create databse, connect, and create AOI data table

# %%
conn = sqlite3.connect(db)
conn.enable_load_extension(True)
conn.execute("SELECT load_extension('mod_spatialite')")

c = conn.cursor()

c.execute('''
    CREATE TABLE IF NOT EXISTS aoi(
        aid INTEGER PRIMARY KEY,
        name VARCHAR(50),
        requestor VARCHAR(25),
        utm VARCHAR(10),
        sqkm NUMERIC(10, 2)
    )
''')

c.execute('''SELECT AddGeometryColumn('aoi', 'geom', 4326, 'POLYGON')''')

conn.commit()
conn.close()

# %% [markdown]
# ### Using the GeoDataFrame, insert the AOIs into the `aois` table

# %%
conn = sqlite3.connect(db)
conn.enable_load_extension(True)
conn.execute("SELECT load_extension('mod_spatialite')")

c = conn.cursor()

for i, row in gdf.iterrows():
    try:
        update_aoi(c, row['aid'], row['name'], row['utm'], row['sqkm'], row['geometry'])
    except Exception as e:
        print("Exception: {} was raised for AOI ID {}".format(e, row['aid']))
print("Done updating AOI table!")

conn.commit()
conn.close()
# Out:
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0001
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0002
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0003
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0004
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0005
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0006
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0007
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0008
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0009
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0010
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0011
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0012
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0013
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0014
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0015
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0016
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0017
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0018
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0019
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0020
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0021
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0022
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0023
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0024
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0025
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0026
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0027
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0028
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0029
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0030
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0031
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0032
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0033
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0034
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0035
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0036
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0037
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0038
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0039
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0040
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0041
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0042
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0043
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0044
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0045
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0046
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0047
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0048
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0049
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0050
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0067
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0124
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0132
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0133
# Exception: UNIQUE constraint failed: aoi.aid was raised for AOI ID 0136
# Done updating AOI table!

# %% [markdown]
# ### Select newly inserted AOIs, make a GeoDataFrame for validation

# %%
conn = sqlite3.connect(db)
conn.enable_load_extension(True)
conn.execute("SELECT load_extension('mod_spatialite')")

c = conn.cursor()

main_columns = list(gdf.columns)[:-1]
main_columns = ', '.join(main_columns)
df = pd.read_sql_query(f"SELECT {main_columns}, AsText(geom) FROM aoi", conn)
df = df.rename(columns={'AsText(geom)': 'geometry'}, errors='raise')
df['geometry'] = shapely.wkt.loads(df['geometry'])
gdf = gpd.GeoDataFrame(df, geometry='geometry')

conn.commit()
conn.close()

gdf.head()
# Out:
#    aid           name         utm     sqkm  \
# 0    1          Kenai  EPSG:32605   416.53
# 1    2  Kalgin Island  EPSG:32605   884.65
# 2    3    Trading Bay  EPSG:32605   529.37
# 3    4        Tuxedni  EPSG:32605   438.72
# 4    5       Upper CI  EPSG:32605  1871.28
#
#                                             geometry
# 0  POLYGON ((-151.59303 60.32094, -151.43153 60.6...
# 1  POLYGON ((-151.73795 60.71243, -151.69676 60.5...
# 2  POLYGON ((-151.34361 61.01015, -151.22669 60.9...
# 3  POLYGON ((-152.60081 60.02992, -152.59393 60.0...
# 4  POLYGON ((-150.67303 60.95571, -151.00321 61.1...

# %%
# Note that the GDF shape matches that from the above
gdf.shape
# Out:
# (55, 5)

# %% [markdown]
# ### Plot Areas of Interest on an Interactive Map

# %%
def style_function(hex_value):
    return {'color': hex_value, 'fillOpacity': 0}

# Add OpenStreetMap as a basemap
map = folium.Map()
folium.TileLayer('openstreetmap').add_to(map)

# Create a GeoJson layer from the response_geojson and add it to the map
folium.GeoJson(
    gdf['geometry'].to_json(),
    style_function = lambda x: style_function('#0000FF')
).add_to(map)

# Zoom to collected images
map.fit_bounds(map.get_bounds(), padding=(100, 100))

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_12212c532c02d00e55ce8feae1041fb2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_12212c532c02d00e55ce8feae1041fb2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_12212c532c02d00e55ce8feae1041fb2 = L.map(
#                 &quot;map_12212c532c02d00e55ce8feae1041fb2&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4f0be3b6f119f0891a3d50e757721cd0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4f0be3b6f119f0891a3d50e757721cd0.addTo(map_12212c532c02d00e55ce8feae1041fb2);
#
#
#             var tile_layer_416d7064bf1983aa6db9223574a5b59d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_416d7064bf1983aa6db9223574a5b59d.addTo(map_12212c532c02d00e55ce8feae1041fb2);
#
#
#         function geo_json_4f6a033dbd8edb2eaa372d87053b0f86_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#0000FF&quot;, &quot;fillOpacity&quot;: 0};
#             }
#         }
#
#         function geo_json_4f6a033dbd8edb2eaa372d87053b0f86_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_4f6a033dbd8edb2eaa372d87053b0f86 = L.geoJson(null, {
#                 onEachFeature: geo_json_4f6a033dbd8edb2eaa372d87053b0f86_onEachFeature,
#
#                 style: geo_json_4f6a033dbd8edb2eaa372d87053b0f86_styler,
#         });
#
#         function geo_json_4f6a033dbd8edb2eaa372d87053b0f86_add (data) {
#             geo_json_4f6a033dbd8edb2eaa372d87053b0f86
#                 .addData(data);
#         }
#             geo_json_4f6a033dbd8edb2eaa372d87053b0f86_add({&quot;bbox&quot;: [-173.973821, -35.305057, 131.607467, 71.634536], &quot;features&quot;: [{&quot;bbox&quot;: [-151.593025, 60.299495, -151.221649, 60.698672], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-151.593025, 60.320938], [-151.431526, 60.698672], [-151.414078, 60.69755], [-151.405518, 60.680618], [-151.385742, 60.657486], [-151.384216, 60.655697], [-151.364304, 60.638313], [-151.357895, 60.61866], [-151.359787, 60.610443], [-151.354324, 60.593536], [-151.342804, 60.577755], [-151.325714, 60.563568], [-151.306747, 60.555996], [-151.285904, 60.550472], [-151.282959, 60.550529], [-151.242752, 60.551289], [-151.236328, 60.543736], [-151.241943, 60.539639], [-151.256363, 60.534649], [-151.256439, 60.525742], [-151.250885, 60.524361], [-151.234161, 60.528431], [-151.221649, 60.528172], [-151.221664, 60.525429], [-151.234665, 60.524319], [-151.247665, 60.521156], [-151.254181, 60.519573], [-151.266647, 60.525082], [-151.272598, 60.533772], [-151.270233, 60.539021], [-151.265579, 60.541294], [-151.255844, 60.540813], [-151.248383, 60.544449], [-151.251144, 60.547199], [-151.26181, 60.54768], [-151.271561, 60.545647], [-151.278091, 60.542007], [-151.29689, 60.509842], [-151.296616, 60.485405], [-151.298843, 60.475819], [-151.307129, 60.439972], [-151.306778, 60.4249], [-151.314331, 60.401157], [-151.30983, 60.386532], [-151.300171, 60.381718], [-151.31636, 60.376041], [-151.31308, 60.383343], [-151.32135, 60.387695], [-151.326889, 60.387936], [-151.348648, 60.378376], [-151.36528, 60.376575], [-151.370285, 60.374599], [-151.388397, 60.367474], [-151.401047, 60.322041], [-151.396515, 60.306282], [-151.398321, 60.299495], [-151.593025, 60.320938]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-152.33905, 60.367845, -151.696757, 60.751831], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-151.737948, 60.712428], [-151.696757, 60.521927], [-151.732147, 60.45267], [-151.96557, 60.378934], [-151.97316, 60.383652], [-151.980713, 60.395741], [-151.99086, 60.395023], [-151.992737, 60.397072], [-151.978958, 60.403053], [-151.959274, 60.417267], [-151.959167, 60.418072], [-151.958435, 60.422981], [-151.930405, 60.437675], [-151.909149, 60.438644], [-151.89946, 60.440952], [-151.893433, 60.438911], [-151.890259, 60.443943], [-151.890793, 60.451252], [-151.898788, 60.463566], [-151.895142, 60.468369], [-151.864243, 60.480545], [-151.83606, 60.487], [-151.840271, 60.491558], [-151.856705, 60.498199], [-151.864456,

# %% [markdown]
# # End
