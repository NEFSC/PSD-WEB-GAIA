# %% [markdown]
# # Build (MGP)
# Using an Area of Interest (AOI) from the `aoi` SQLite Database, queries the Maxar Geospatial Platform API for data over a given time period, builds the `mgp` table from these results, and then populates the table with these values. Other notebooks should be used for adding additional records to the table.
#
# ### Import libraries

# %%
# Basic stack
from datetime import datetime

# Web Stack
import json
import requests

# Database stack
import sqlite3

# Data Science stack
import shapely
from shapely.geometry import box, Polygon
import pandas as pd
import geopandas as gpd
import folium

# Custom stack
import sys; sys.path.append("../../")
from MGP import security, search

# %% [markdown]
# ### User defined variables

# %%
aoi_id = '6'
collections = ["wv03-vnir"]
start_date = '2014-08-13'
end_date = '2024-05-31'
where_clause = "eo:cloud_cover <= 90 and off_nadir_avg <= 90"
limit = 1_000
db = "C:/gis/gaia/data/databases/gaia.db"

# %% [markdown]
# ### User defined functions

# %%
def update_mgp(c, entity_id, column_name, column_value):
    """ Updates EE table values of a given column with a given value using the 
            ENTITY ID as the selection criteria for the update.

        C - A cursor
        ENTITY ID - An entity id from EarthExplorer
        COLUMN NAME - A column name within the EE table to be updated
        COLUMN VALUE - A value to update the column
    """
    force_string_list = ['platform', 'instruments']
    force_date_list2 = ['datetime']
    force_geom_list = ['bbox']
    
    if column_name in force_string_list:
        sql_string = f"UPDATE mgp SET {column_name} = \"{column_value}\" WHERE id = \"{entity_id}\""
        c.execute(sql_string)
    
    elif column_name in force_date_list2:
        sql_string = f"UPDATE mgp SET {column_name} = "
        sql_string = sql_string + "? WHERE id = ?"
        c.execute(sql_string, (column_value, entity_id))
    
    elif column_name in force_geom_list:
        sql_string = f"UPDATE mgp SET {column_name} = GeomFromText(\"{column_value}\") WHERE id = \"{entity_id}\""
        c.execute(sql_string)
    
    else:
        sql_string = f"UPDATE mgp SET {column_name} = {column_value} WHERE id = \"{entity_id}\""
        c.execute(sql_string)

def database_activity(db, entity_id, column_name, column_value, activity='update'):
    """ Wrapper function for activities related to database management.
            Currently only supports UPDATING based on EarthExplorer 
            Entity ID values.

        Is dependent on the UPDATE EE function above.

        DB - A database target
        ENTITY ID - An EarthExplorer Entity ID uniquely identifying
            the record of interest.
        COLUMN NAME - The column to be updated
        COLUMN VALUE - The value of the column to be updated
        ACTIVITY - The activity to be carried out. Currently only
            supports UPDATE.
    """
    conn = sqlite3.connect(db)
    conn.enable_load_extension(True)
    conn.execute("SELECT load_extension('mod_spatialite')")
    c = conn.cursor()

    if activity == 'update':
        try:
            update_mgp(c, entity_id, column_name, column_value)
        except Exception as e:
            print("Exception: {} was raised for Entity ID {}".format(e, row['entity_id']))
    else:
        print("Your activity method is not currently supported.")
    
    conn.commit()
    conn.close()

def insert_mgp(c, iid):
    """ Inserts Maxar Geospatial Platform IDs into the MGP Data Table.
            The IDs are the Primary Key for the datatable since it is
            unique

        C - A cursor
        ID - An ID value from Maxar Geospatial Platform
    """
    sql_string = f"INSERT INTO mgp(id) VALUES (\"{iid}\")"
    c.execute(sql_string)

# %% [markdown]
# ### Get MGP Token
# Hint: ###

# %%
token_file = security.fetch_auth()
# Out:
# Enter your username:   john.wall@noaa.gov
# Enter your password:   ········
# Writing file now!

# %% [markdown]
# ### Retreve the Area of Interest record from the `aoi` table corresponding to the supplied DAR number

# %%
conn = sqlite3.connect(db)
conn.enable_load_extension(True)
conn.execute("SELECT load_extension('mod_spatialite')")

c = conn.cursor()

sql_string = f"SELECT aid, name, sqkm, AsText(geom) FROM aoi WHERE aid={aoi_id}"
df = pd.read_sql_query(sql_string, conn)
df = df.rename(columns={'AsText(geom)': 'geometry'}, errors='raise')
df['geometry'] = shapely.wkt.loads(df['geometry'])
gdf_aoi = gpd.GeoDataFrame(df, geometry='geometry')

conn.commit()
conn.close()

gdf_aoi
# Out:
#    aid          name     sqkm  \
# 0    6  Cape Cod Bay  1347.04
#
#                                             geometry
# 0  POLYGON ((-70.11938 42.10724, -70.52387 42.109...

# %% [markdown]
# ### Search MGP

# %%
gdf_json = gdf_aoi['geometry'].to_json()

response, id_list = search.search(
    collections = collections,
    start = start_date,
    end = end_date,
    where = where_clause,
    geometry = gdf_json,
    limit = limit
)

print("Here are some example ImageIDs your query returned: {}".format(id_list[0:5]))
# Out:
# {
#   "datetime": "2014-08-13/2024-05-31",
#   "where": "eo:cloud_cover <= 90 and off_nadir_avg <= 90",
#   "intersects": {
#     "type": "Polygon",
#     "coordinates": [
#       [
#         [
#           -70.119385,
#           42.107239
#         ],
#         [
#           -70.523865,
#           42.109436
#         ],
#         [
#           -70.526001,
#           41.747925
#         ],
#         [
#           -70.121399,
#           41.745544
#         ],
#         [
#           -70.119385,
#           42.107239
#         ]
#       ]
#     ]
#   },
#   "limit": 1000,
#   "page": 1,
#   "collections": [
#     "wv03-vnir"
#   ]
# }
# Total of 168 objects returned
# Here are some example ImageIDs your query returned: ['1040010093625500', '10400100959B5400', '1040010096672600', '1040010091057E00', '1040010093A5AA00']

# %%
response.json()
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'id': '1040010093625500',
#    'bbox': [-70.613369, 41.780362, -70.333672, 42.162377],
#    'type': 'Feature',
#    'links': [{'rel': 'collection',
#      'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir'},
#     {'rel': 'self',
#      'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/1040010093625500'},
#     {'rel': 'root', 'href': 'https://api.maxar.com/discovery/v1/'},
#     {'rel': 'order-map-ready',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/map-ready/order',
#      'type': 'application/json'},
#     {'rel': 'order-system-ready',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/system-ready/order',
#      'type': 'application/json'},
#     {'rel': 'order-view-ready',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/view-ready/order',
#      'type': 'application/json'},
#     {'rel': 'order-view-ready-ortho',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/view-ready-ortho/order',
#      'type': 'application/json'}],
#    'assets': {'browse': {'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/1040010093625500/assets/collections/dg-archive/assets/browse/1040010093625500.browse.tif',
#      'type': 'image/tiff; application=geotiff',
#      'title': 'Browse Image'},
#     'cloud-cover': {'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/1040010093625500/assets/collections/wv03-vnir/assets/cloud-cover/1040010093625500.cloud.json',
#      'type': 'application/geo+json',
#      'title': 'Cloud Cover'},
#     'sample-point-set': {'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/1040010093625500/assets/collections/wv03-vnir/assets/sample-point-sets/1040010093625500.sample-points.json',
#      'type': 'application/geo+json',
#      'title': 'Sample Point Set'}},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-70.613369, 42.162377],
#       [-70.613063, 42.123575],
#       [-70.612764, 42.084788],
#       [-70.612448, 42.046033],
#       [-70.612168, 42.007384],
#       [-70.611918, 41.968795],
#       [-70.611438, 41.930136],
#       [-70.610859, 41.891483],
#       [-70.610805, 41.853055],
#       [-70.610668, 41.820121],
#       [-70.335952, 41.780362],
#       [-70.335732, 41.813473],
#       [-70.33547, 41.851754],
#       [-70.335194, 41.890077],
#       [-70.334904, 41.928431],
#       [-70.334625, 41.966798],
#       [-70.334366, 42.005222],
#       [-70.334141, 42.043748],
#       [-70.333902, 42.082306],
#       [-70.333672, 42.12088],
#       [-70.613369, 42.162377]]]},
#    'collection': 'wv03-vnir',
#    'properties': {'gsd': 0.489590036,
#     'title': 'Maxar WV03 Image 1040010093625500',
#     'datetime': '2024-05-10T15:12:09.830632Z',
#     'eo:bands': [{'name': 'pan', 'center_wavelength': 625},
#      {'name': 'nir2', 'center_wavelength': 948},
#      {'name': 'nir1', 'center_wavelength': 832},
#      {'name': 'red_edge', 'center_wavelength': 723.5},
#      {'name': 'red', 'center_wavelength': 661},
#      {'name': 'yellow', 'center_wavelength': 531},
#      {'name': 'green', 'center_wavelength': 546.5},
#      {'name': 'blue', 'center_wavelength': 481},
#      {'name': 'coastal', 'center_wavelength': 425.5}],
#     'platform': 'worldview-03',
#     'instruments': ['VNIR'],
#     'associations': [],
#     'view:azimuth': 298.21721,
#     'constellation': 'maxar',
#     'off_nadir_avg': 38.731296,
#     'off_nadir_end': 38.52327,
#     'off_nadir_max': 38.944237,
#     'off_nadir_min': 38.52327,
#     'rda_available': False,
#     'eo:cloud_cover': 67.75605514842876,
#     'scan_direction': 'forward',
#     'view:off_nadir': 38.731296,
#     'off_nadir_start': 38.944237,
#     'collect_time_end': '2024-05-10T15:12:14.594568Z',
#     'view:sun_azimuth': 135.97089,
#     'raw_archive_state': 'online',
#     'collect_time_start': '2024-05-10T15:12:09.830632Z',
#     'pan_resolution_avg': 0.489590036,
#     'pan_resolution_end': 0.48673686,
#     'pan_resolution_max': 0.4924899,
#     'pan_resolution_min': 0.48673686,
#     'view:sun_elevation': 59.8401956,
#     'multi_resolution_avg': 1.9578222,
#     'multi_resolution_end': 1.9464297,
#     'multi_resolution_max': 1.9694006,
#     'multi_resolution_min': 1.9464297,
#     'pan_resolution_start': 0.4924899,
#     'acquisition_rev_number': 52804,
#     'multi_resolution_start': 1.9694006,
#     'view:sun_elevation_max': 59.975544,
#     'view:sun_elevation_min': 59.701538,
#     'geolocation_uncertainty': 28.615093,
#     'stereo_pair_identifiers': [],
#     'spacecraft_to_target_azimuth_avg': 298.21721,
#     'spacecraft_to_target_azimuth_end': 297.90628,
#     'spacecraft_to_target_azimuth_max': 298.5379,
#     'spacecraft_to_target_azimuth_min': 297.90628,
#     'target_to_spacecraft_azimuth_avg': 118.2172119140625,
#     'target_to_spacecraft_azimuth_end': 117.90628051757812,
#     'target_to_spacecraft_azimuth_max': 118.53790283203125,
#     'target_to_spacecraft_azimuth_min': 117.90628051757812,
#     'spacecraft_to_target_azimuth_start': 298.5379,
#     'target_to_spacecraft_azimuth_start': 118.53790283203125,
#     'target_to_spacecraft_elevation_avg': 46.67035718215191,
#     'target_to_spacecraft_elevation_end': 46.91495337723862,
#     'target_to_spacecraft_elevation_max': 46.91495337723862,
#     'target_to_spacecraft_elevation_min': 46.41982562092522,
#     'target_to_spacecraft_elevation_start': 46.41982562092522},
#    'stac_version': '1.0.0',
#    'stac_extensions': ['https://stac-extensions.github.io/eo/v1.0.0/schema.json',
#     'https://stac-extensions.github.io/view/v1.0.0/schema.json']},
#   {'id': '10400100959B5400',
#    'bbox': [-70.361882, 41.802739, -70.092829, 42.154464],
#    'type': 'Feature',
#    'links': [{'rel': 'collection',
#      'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir'},
#     {'rel': 'self',
#      'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/10400100959B5400'},
#     {'rel': 'root', 'href': 'https://api.maxar.com/discovery/v1/'},
#     {'rel': 'order-map-ready',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/map-ready/order',
#      'type': 'application/json'},
#     {'rel': 'order-system-ready',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/system-ready/order',
#      'type': 'application/json'},
#     {'rel': 'order-view-ready',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/view-ready/order',
#      'type': 'application/json'},
#     {'rel': 'order-view-ready-ortho',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/view-ready-ortho/order',
#      'type': 'application/json'}],
#    'assets': {'browse': {'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/10400100959B5400/assets/collections/dg-archive/assets/browse/10400100959B5400.browse.tif',
#      'type': 'image/tiff; application=geotiff',
#      'title': 'Browse Image'},
#     'cloud-cover': {'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/10400100959B5400/assets/collections/wv03-vnir/assets/cloud-cover/10400100959B5400.cloud.json',
#      'type': 'application/geo+json',
#      'title': 'Cloud Cover'},
#     'sample-point-set': {'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/10400100959B5400/assets/collections/wv03-vnir/assets/sample-point-sets/10400100959B5400.sample-points.json',
#      'type': 'application/geo+json',
#      'title': 'Sample Point Set'}},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-70.094586, 41.802739],
#       [-70.094394, 41.83813],
#       [-70.094257, 41.873594],
#       [-70.094089, 41.909195],
#       [-70.093939, 41.944894],
#       [-70.093746, 41.980697],
#       [-70.093526, 42.016602],
#       [-70.093186, 42.052622],
#       [-70.093069, 42.088825],
#       [-70.092829, 42.123431],
#       [-70.361882, 42.154464],
#       [-70.361651, 42.118083],
#       [-70.361391, 42.08051],
#       [-70.361193, 42.043082],
#       [-70.360998, 42.005803],
#       [-70.360797, 41.968631],
#       [-70.360589, 41.93157],
#       [-70.360428, 41.894618],
#       [-70.360267, 41.857809],
#       [-70.36019, 41.821076],
#       [-70.094586, 41.802739]]]},
#    'collection': 'wv03-vnir',
#    'properties': {'gsd': 0.465732354,
#     'title': 'Maxar WV03 Image 10400100959B5400',
#     'datetime': '2024-05-10T15:11:58.030657Z',
#     'eo:bands': [{'name': 'pan', 'center_wavelength': 625},
#      {'name': 'nir2', 'center_wavelength': 948},
#      {'name': 'nir1', 'center_wavelength': 832},
#      {'name': 'red_edge', 'center_wavelength': 723.5},
#      {'name': 'red', 'center_wavelength': 661},
#      {'name': 'yellow', 'center_wavelength': 531},
#      {'name': 'green', 'center_wavelength': 546.5},
#      {'name': 'blue', 'center_wavelength': 481},
#      {'name': 'coastal', 'center_wavelength': 425.5}],
#     'platform': 'worldview-03',
#     'instruments': ['VNIR'],
#     'associations': [],
#     'view:azimuth': 290.060698,
#     'constellation': 'maxar',
#     'off_nadir_avg': 36.9672,
#     'off_nadir_end': 37.392902,
#     'off_nadir_max': 37.392902,
#     'off_nadir_min': 36.594574,
#     'rda_available': False,
#     'eo:cloud_cover': 69.66517863469524,
#     'scan_direction': 'reverse',
#     'view:off_nadir': 36.9672,
#     'off_nadir_start': 36.594574,
#     'collect_time_end': '2024-05-10T15:12:02.843392Z',
#     'view:sun_azimuth': 136.29946,
#     'raw_archive_state': 'online',
#     'collect_time_start': '2024-05-10T15:11:58.030657Z',
#     'pan_resolution_avg': 0.465732354,
#     'pan_resolution_end': 0.4713697,
#     'pan_resolution_max': 0.4713697,
#     'pan_resolution_min': 0.46075904,
#     'view:sun_elevation': 59.9334014,
#     'multi_resolution_avg': 1.8618668,
#     'multi_resolution_end': 1.8841145,
#     'multi_resolution_max': 1.8841145,
#     'multi_resolution_min': 1.8422846,
#     'pan_resolution_start': 0.46075904,
#     'acquisition_rev_number': 52804,
#     'multi_resolution_start': 1.8422846,
#     'view:sun_elevation_max': 60.058,
#     'view:sun_elevation_min': 59.814587,
#     'geolocation_uncertainty': 27.206902,
#     'stereo_pair_identifiers': [],
#     'spacecraft_to_target_azimuth_avg': 290.060698,
#     'spacecraft_to_target_azimuth_end': 294.10425,
#     'spacecraft_to_target_azimuth_max': 294.10425,
#     'spacecraft_to_target_azimuth_min': 285.71716,
#     'target_to_spacecraft_azimuth_avg': 110.06069946289062,
#     'target_to_spacecraft_azimuth_end': 114.104248046875,
#     'target_to_spacecraft_azimuth_max': 114.104248046875,
#     'target_to_spacecraft_azimuth_min': 105.7171630859375,
#     'spacecraft_to_target_azimuth_start': 285.71716,
#     'target_to_spacecraft_azimuth_start': 105.7171630859375,
#     'target_to_spacecraft_elevation_avg': 48.73567774756927,
#     'target_to_spacecraft_elevation_end': 48.23911059579599,
#     'target_to_spacecraft_elevation_max': 49.16989045924518,
#     'target_to_spacecraft_elevation_min': 48.23911059579599,
#     'target_to_spacecraft_elevation_start': 49.16989045924518},
#    'stac_version': '1.0.0',
#    'stac_extensions': ['https://stac-extensions.github.io/eo/v1.0.0/schema.json',
#     'https://stac-extensions.github.io/view/v1.0.0/schema.json']},
#   {'id': '1040010096672600',
#    'bbox': [-70.201235, 41.465429, -69.992088, 42.029869],
#    'type': 'Feature',
#    'links': [{'rel': 'collection',
#      'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir'},
#     {'rel': 'self',
#      'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/1040010096672600'},
#     {'rel': 'root', 'href': 'https://api.maxar.com/discovery/v1/'},
#     {'rel': 'order-map-ready',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/map-ready/order',
#      'type': 'application/json'},
#     {'rel': 'order-system-ready',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/system-ready/order',
#      'type': 'application/json'},
#     {'rel': 'order-view-ready',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/view-ready/order',
#      'type': 'application/json'},
#     {'rel': 'order-view-ready-ortho',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/view-ready-ortho/order',
#      'type': 'application/json'}],
#    'assets': {'browse': {'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/1040010096672600/assets/collections/dg-archive/assets/browse/1040010096672600.browse.tif',
#      'type': 'image/tiff; application=geotiff',
#      'title': 'Browse Image'},
#     'cloud-cover': {'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/1040010096672600/assets/collections/wv03-vnir/assets/cloud-cover/1040010096672600.cloud.json',
#      'type': 'application/geo+json',
#      'title': 'Cloud Cover'},
#     'sample-point-set': {'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/1040010096672600/assets/collections/wv03-vnir/assets/sample-point-sets/1040010096672600.sample-points.json',
#      'type': 'application/geo+json',
#      'title': 'Sample Point Set'}},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-69.992088, 42.010437],
#       [-70.201235, 42.029869],
#       [-70.20113, 42.007293],
#       [-70.200956, 41.973936],
#       [-70.200783, 41.940595],
#       [-70.200642, 41.907317],
#       [-70.200503, 41.874056],
#       [-70.200351, 41.840806],
#       [-70.200182, 41.807579],
#       [-70.200021, 41.774371],
#       [-70.199819, 41.741153],
#       [-70.199735, 41.7266],
#       [-70.199666, 41.717384],
#       [-70.199638, 41.709912],
#       [-70.199627, 41.707965],
#       [-70.199491, 41.67483],
#       [-70.199394, 41.641721],
#       [-70.199267, 41.608612],
#       [-70.19912, 41.575518],
#       [-70.198949, 41.542455],
#       [-70.198781, 41.509398],
#       [-70.198659, 41.483827],
#       [-69.99474, 41.465429],
#       [-69.994621, 41.491034],
#       [-69.994478, 41.524018],
#       [-69.994331, 41.557007],
#       [-69.994169, 41.59003],
#       [-69.993989, 41.623069],
#       [-69.99383, 41.656127],
#       [-69.993575, 41.689157],
#       [-69.993465, 41.722278],
#       [-69.993199, 41.75536],
#       [-69.993109, 41.78852],
#       [-69.993013, 41.821696],
#       [-69.992782, 41.854844],
#       [-69.992622, 41.888038],
#       [-69.992385, 41.921216],
#       [-69.992252, 41.954488],
#       [-69.992188, 41.987804],
#       [-69.992088, 42.010437]]]},
#    'collection': 'wv03-vnir',
#    'properties': {'gsd': 0.3877511242857143,
#     'title': 'Maxar WV03 Image 1040010096672600',
#     'datetime': '2024-05-04T15:18:49.787012Z',
#     'eo:bands': [{'name': 'pan', 'center_wavelength': 625},
#      {'name': 'nir2', 'center_wavelength': 948},
#      {'name': 'nir1', 'center_wavelength': 832},
#      {'name': 'red_edge', 'center_wavelength': 723.5},
#      {'name': 'red', 'center_wavelength': 661},
#      {'name': 'yellow', 'center_wavelength': 531},
#      {'name': 'green', 'center_wavelength': 546.5},
#      {'name': 'blue', 'center_wavelength': 481},
#      {'name': 'coastal', 'center_wavelength': 425.5}],
#     'platform': 'worldview-03',
#     'instruments': ['VNIR'],
#     'associations': [],
#     'view:azimuth': 300.87728142857145,
#     'constellation': 'maxar',
#     'off_nadir_avg': 28.198752,
#     'off_nadir_end': 27.83487,
#     'off_nadir_max': 28.656466,
#     'off_nadir_min': 27.83487,
#     'rda_available': False,
#     'eo:cloud_cover': 85.42766576107198,
#     'scan_direction': 'forward',
#     'view:off_nadir': 28.198752,
#     'off_nadir_start': 28.656466,
#     'collect_time_end': '2024-05-04T15:18:58.346939Z',
#     'view:sun_azimuth': 140.54845857142857,
#     'raw_archive_state': 'online',
#     'collect_time_start': '2024-05-04T15:18:49.787012Z',
#     'pan_resolution_avg': 0.3877511242857143,
#     'pan_resolution_end': 0.38524905,
#     'pan_resolution_max': 0.39108658,
#     'pan_resolution_min': 0.38524905,
#     'view:sun_elevation': 59.617618,
#     'multi_resolution_avg': 1.5668424428571428,
#     'multi_resolution_end': 1.5634843,
#     'multi_resolution_max': 1.5742657,
#     'multi_resolution_min': 1.5634843,
#     'pan_resolution_start': 0.39108658,
#     'acquisition_rev_number': 52715,
#     'multi_resolution_start': 1.5742657,
#     'view:sun_elevation_max': 59.818703,
#     'view:sun_elevation_min': 59.363625,
#     'geolocation_uncertainty': 4.660181751148633,
#     'stereo_pair_identifiers': [],
#     'spacecraft_to_target_azimuth_avg': 300.87728142857145,
#     'spacecraft_to_target_azimuth_end': 300.93692,
#     'spacecraft_to_target_azimuth_max': 300.93692,
#     'spacecraft_to_target_azimuth_min': 300.82065,
#     'target_to_spacecraft_azimuth_avg': 118.88648318617649,
#     'target_to_spacecraft_azimuth_end': 119.00699791786838,
#     'target_to_spacecraft_azimuth_max': 119.00699791786838,
#     'target_to_spacecraft_azimuth_min': 118.75274244542068,
#     'spacecraft_to_target_azimuth_start': 300.82065,
#     'target_to_spacecraft_azimuth_start': 118.75274244542068,
#     'target_to_spacecraft_elevation_avg': 58.67894037923716,
#     'target_to_spacecraft_elevation_end': 59.090411268301,
#     'target_to_spacecraft_elevation_max': 59.090411268301,
#     'target_to_spacecraft_elevation_min': 58.16096787397326,
#     'target_to_spacecraft_elevation_start': 58.16096787397326},
#    'stac_version': '1.0.0',
#    'stac_extensions': ['https://stac-extensions.github.io/eo/v1.0.0/schema.json',
#     'https://stac-extensions.github.io/view/v1.0.0/schema.json']},
#   {'id': '1040010091057E00',
#    'bbox': [-70.671117, 41.777031, -70.440299, 42.17897],
#    'type': 'Feature',
#    'links': [{'rel': 'collection',
#      'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir'},
#     {'rel': 'self',
#      'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/1040010091057E00'},
#     {'rel': 'root', 'href': 'https://api.maxar.com/discovery/v1/'},
#     {'rel': 'order-map-ready',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/map-ready/order',
#      'type': 'application/json'},
#     {'rel': 'order-system-ready',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/system-ready/order',
#      'type': 'application/json'},
#     {'rel': 'order-view-ready',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/view-ready/order',
#      'type': 'application/json'},
#     {'rel': 'order-view-ready-ortho',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/view-ready-ortho/order',
#      'type': 'application/json'}],
#    'assets': {'browse': {'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/1040010091057E00/assets/collections/dg-archive/assets/browse/1040010091057E00.browse.tif',
#      'type': 'image/tiff; application=geotiff',
#      'title': 'Browse Image'},
#     'cloud-cover': {'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/1040010091057E00/assets/collections/wv03-vnir/assets/cloud-cover/1040010091057E00.cloud.json',
#      'type': 'application/geo+json',
#      'title': 'Cloud Cover'},
#     'sample-point-set': {'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/1040010091057E00/assets/collections/wv03-vnir/assets/sample-point-sets/1040010091057E00.sample-points.json',
#      'type': 'application/geo+json',
#      'title': 'Sample Point Set'}},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-70.440299, 42.125159],
#       [-70.671117, 42.17897],
#       [-70.670901, 42.165593],
#       [-70.670132, 42.118729],
#       [-70.66934, 42.072441],
#       [-70.668629, 42.026884],
#       [-70.667982, 41.981868],
#       [-70.667092, 41.937118],
#       [-70.666373, 41.893222],
#       [-70.665672, 41.849829],
#       [-70.665402, 41.820741],
#       [-70.445785, 41.777031],
#       [-70.445755, 41.778814],
#       [-70.445174, 41.813914],
#       [-70.444699, 41.847583],
#       [-70.444624, 41.852491],
#       [-70.444501, 41.861344],
#       [-70.444144, 41.883953],
#       [-70.444048, 41.89027],
#       [-70.443825, 41.904196],
#       [-70.443357, 41.93356],
#       [-70.442976, 41.956705],
#       [-70.442414, 41.991671],
#       [-70.441951, 42.021749],
#       [-70.441728, 42.036222],
#       [-70.441521, 42.049312],
#       [-70.441249, 42.066726],
#       [-70.441013, 42.081392],
#       [-70.440513, 42.112285],
#       [-70.440299, 42.125159]]]},
#    'collection': 'wv03-vnir',
#    'properties': {'gsd': 0.477092496,
#     'title': 'Maxar WV03 Image 1040010091057E00',
#     'datetime': '2024-03-14T15:21:50.586824Z',
#     'eo:bands': [{'name': 'pan', 'center_wavelength': 625},
#      {'name': 'nir2', 'center_wavelength': 948},
#      {'name': 'nir1', 'center_wavelength': 832},
#      {'name': 'red_edge', 'center_wavelength': 723.5},
#      {'name': 'red', 'center_wavelength': 661},
#      {'name': 'yellow', 'center_wavelength': 531},
#      {'name': 'green', 'center_wavelength': 546.5},
#      {'name': 'blue', 'center_wavelength': 481},
#      {'name': 'coastal', 'center_wavelength': 425.5}],
#     'platform': 'worldview-03',
#     'instruments': ['VNIR'],
#     'associations': [],
#     'view:azimuth': 332.149348,
#     'constellation': 'maxar',
#     'off_nadir_avg': 37.5087652,
#     'off_nadir_end': 38.975697,
#     'off_nadir_max': 38.975697,
#     'off_nadir_min': 35.814953,
#     'rda_available': False,
#     'eo:cloud_cover': 30.34220338339807,
#     'scan_direction': 'reverse',
#     'view:off_nadir': 37.5087652,
#     'off_nadir_start': 35.814953,
#     'collect_time_end': '2024-03-14T15:21:54.900361Z',
#     'view:sun_azimuth': 149.478354,
#     'raw_archive_state': 'online',
#     'collect_time_start': '2024-03-14T15:21:50.586824Z',
#     'pan_resolution_avg': 0.477092496,
#     'pan_resolution_end': 0.49676925,
#     'pan_resolution_max': 0.49676925,
#     'pan_resolution_min': 0.45525545,
#     'view:sun_elevation': 41.5940888,
#     'multi_resolution_avg': 1.82561222,
#     'multi_resolution_end': 1.837553,
#     'multi_resolution_max': 1.837553,
#     'multi_resolution_min': 1.8175597,
#     'pan_resolution_start': 0.45525545,
#     'acquisition_rev_number': 51958,
#     'multi_resolution_start': 1.8213543,
#     'view:sun_elevation_max': 41.76508,
#     'view:sun_elevation_min': 41.442234,
#     'geolocation_uncertainty': 3.469583222419424,
#     'stereo_pair_identifiers': [],
#     'spacecraft_to_target_azimuth_avg': 332.149348,
#     'spacecraft_to_target_azimuth_end': 334.28754,
#     'spacecraft_to_target_azimuth_max': 334.28754,
#     'spacecraft_to_target_azimuth_min': 329.54147,
#     'target_to_spacecraft_azimuth_avg': 150.48960535887744,
#     'target_to_spacecraft_azimuth_end': 152.63617337494026,
#     'target_to_spacecraft_azimuth_max': 152.63617337494026,
#     'target_to_spacecraft_azimuth_min': 147.87297433083634,
#     'spacecraft_to_target_azimuth_start': 329.54147,
#     'target_to_spacecraft_azimuth_start': 147.87297433083634,
#     'target_to_spacecraft_elevation_avg': 47.914827615940446,
#     'target_to_spacecraft_elevation_end': 46.191686776358694,
#     'target_to_spacecraft_elevation_max': 49.89679413743995,
#     'target_to_spacecraft_elevation_min': 46.191686776358694,
#     'target_to_spacecraft_elevation_start': 49.89679413743995},
#    'stac_version': '1.0.0',
#    'stac_extensions': ['https://stac-extensions.github.io/eo/v1.0.0/schema.json',
#     'https://stac-extensions.github.io/view/v1.0.0/schema.json']},
#   {'id': '1040010093A5AA00',
#    'bbox': [-70.285153, 41.799586, -70.078809, 42.149836],
#    'type': 'Feature',
#    'links': [{'rel': 'collection',
#      'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir'},
#     {'rel': 'self',
#      'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/1040010093A5AA00'},
#     {'rel': 'root', 'href': 'https://api.maxar.com/discovery/v1/'},
#     {'rel': 'order-map-ready',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/map-ready/order',
#      'type': 'application/json'},
#     {'rel': 'order-system-ready',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/system-ready/order',
#      'type': 'application/json'},
#     {'rel': 'order-view-ready',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/view-ready/order',
#      'type': 'application/json'},
#     {'rel': 'order-view-ready-ortho',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/view-ready-ortho/order',
#      'type': 'application/json'}],
#    'assets': {'browse': {'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/1040010093A5AA00/assets/collections/dg-archive/assets/browse/1040010093A5AA00.browse.tif',
#      'type': 'image/tiff; application=geotiff',
#      'title': 'Browse Image'},
#     'cloud-cover': {'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/1040010093A5AA00/assets/collections/wv03-vnir/assets/cloud-cover/1040010093A5AA00.cloud.json',
#      'type': 'application/geo+json',
#      'title': 'Cloud Cover'},
#     'sample-point-set': {'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/1040010093A5AA00/assets/collections/wv03-vnir/assets/sample-point-sets/1040010093A5AA00.sample-points.json',
#      'type': 'application/geo+json',
#      'title': 'Sample Point Set'}},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-70.078809, 42.119106],
#       [-70.285153, 42.149836],
#       [-70.28498, 42.135513],
#       [-70.284541, 42.098277],
#       [-70.284094, 42.061366],
#       [-70.28364, 42.024815],
#       [-70.283232, 41.988554],
#       [-70.282864, 41.952594],
#       [-70.282462, 41.916953],
#       [-70.282104, 41.881586],
#       [-70.28173, 41.84654],
#       [-70.28152, 41.822826],
#       [-70.082496, 41.799586],
#       [-70.082346, 41.812863],
#       [-70.082127, 41.833727],
#       [-70.082025, 41.843446],
#       [-70.081888, 41.856942],
#       [-70.0818, 41.864744],
#       [-70.081765, 41.868091],
#       [-70.08138, 41.902773],
#       [-70.081129, 41.926385],
#       [-70.081061, 41.931836],
#       [-70.080997, 41.937711],
#       [-70.080827, 41.950737],
#       [-70.080693, 41.961544],
#       [-70.080265, 41.996984],
#       [-70.079813, 42.032668],
#       [-70.079449, 42.068811],
#       [-70.079314, 42.079491],
#       [-70.079304, 42.080542],
#       [-70.079074, 42.098497],
#       [-70.078989, 42.105209],
#       [-70.078836, 42.117049],
#       [-70.078809, 42.119106]]]},
#    'collection': 'wv03-vnir',
#    'properties': {'gsd': 0.400867096,
#     'title': 'Maxar WV03 Image 1040010093A5AA00',
#     'datetime': '2024-03-14T15:21:27.286870Z',
#     'eo:bands': [{'name': 'pan', 'center_wavelength': 625},
#      {'name': 'nir2', 'center_wavelength': 948},
#      {'name': 'nir1', 'center_wavelength': 832},
#      {'name': 'red_edge', 'center_wavelength': 723.5},
#      {'name': 'red', 'center_wavelength': 661},
#      {'name': 'yellow', 'center_wavelength': 531},
#      {'name': 'green', 'center_wavelength': 546.5},
#      {'name': 'blue', 'center_wavelength': 481},
#      {'name': 'coastal', 'center_wavelength': 425.5}],
#     'platform': 'worldview-03',
#     'instruments': ['VNIR'],
#     'associations': [],
#     'view:azimuth': 320.08349,
#     'constellation': 'maxar',
#     'off_nadir_avg': 29.9311988,
#     'off_nadir_end': 31.411566,
#     'off_nadir_max': 31.411566,
#     'off_nadir_min': 28.186523,
#     'rda_available': False,
#     'eo:cloud_cover': 71.98774103059377,
#     'scan_direction': 'reverse',
#     'view:off_nadir': 29.9311988,
#     'off_nadir_start': 28.186523,
#     'collect_time_end': '2024-03-14T15:21:32.150006Z',
#     'view:sun_azimuth': 149.822968,
#     'raw_archive_state': 'online',
#     'collect_time_start': '2024-03-14T15:21:27.286870Z',
#     'pan_resolution_avg': 0.400867096,
#     'pan_resolution_end': 0.4132963,
#     'pan_resolution_max': 0.4132963,
#     'pan_resolution_min': 0.38773453,
#     'view:sun_elevation': 41.6979866,
#     'multi_resolution_avg': 1.54537942,
#     'multi_resolution_end': 1.5553406,
#     'multi_resolution_max': 1.5553406,
#     'multi_resolution_min': 1.5335287,
#     'pan_resolution_start': 0.38773453,
#     'acquisition_rev_number': 51958,
#     'multi_resolution_start': 1.5335287,
#     'view:sun_elevation_max': 41.85684,
#     'view:sun_elevation_min': 41.56463,
#     'geolocation_uncertainty': 3.0099511306118427,
#     'stereo_pair_identifiers': [],
#     'spacecraft_to_target_azimuth_avg': 320.08349,
#     'spacecraft_to_target_azimuth_end': 323.7439,
#     'spacecraft_to_target_azimuth_max': 323.7439,
#     'spacecraft_to_target_azimuth_min': 315.34995,
#     'target_to_spacecraft_azimuth_avg': 138.46276814618386,
#     'target_to_spacecraft_azimuth_end': 142.12260074391966,
#     'target_to_spacecraft_azimuth_max': 142.12260074391966,
#     'target_to_spacecraft_azimuth_min': 133.7317149761974,
#     'spacecraft_to_target_azimuth_start': 315.34995,
#     'target_to_spacecraft_azimuth_start': 133.7317149761974,
#     'target_to_spacecraft_elevation_avg': 56.66545651174477,
#     'target_to_spacecraft_elevation_end': 54.97325969876794,
#     'target_to_spacecraft_elevation_max': 58.65634468699671,
#     'target_to_spacecraft_elevation_min': 54.97325969876794,
#     'target_to_spacecraft_elevation_start': 58.65634468699671},
#    'stac_version': '1.0.0',
#    'stac_extensions': ['https://stac-extensions.github.io/eo/v1.0.0/schema.json',
#     'https://stac-extensions.github.io/view/v1.0.0/schema.json']},
#   {'id': '1040010093467000',
#    'bbox': [-70.546477, 41.779481, -70.297866, 42.179218],
#    'type': 'Feature',
#    'links': [{'rel': 'collection',
#      'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir'},
#     {'rel': 'self',
#      'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/1040010093467000'},
#     {'rel': 'root', 'href': 'https://api.maxar.com/discovery/v1/'},
#     {'rel': 'order-map-ready',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/map-ready/order',
#      'type': 'application/json'},
#     {'rel': 'order-system-ready',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/system-ready/order',
#      'type': 'application/json'},
#     {'rel': 'order-view-ready',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/view-ready/order',
#      'type': 'application/json'},
#     {'rel': 'order-view-ready-ortho',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/view-ready-ortho/order',
#      'type': 'application/json'}],
#    'assets': {'browse': {'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/1040010093467000/assets/collections/dg-archive/assets/browse/1040010093467000.browse.tif',
#      'type': 'image/tiff; application=geotiff',
#      'title': 'Browse Image'},
#     'cloud-cover': {'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/1040010093467000/assets/collections/wv03-vnir/assets/cloud-cover/1040010093467000.cloud.json',
#      'type': 'application/geo+json',
#      'title': 'Cloud Cover'},
#     'sample-point-set': {'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/1040010093467000/assets/collections/wv03-vnir/assets/sample-point-sets/1040010093467000.sample-points.json',
#      'type': 'application/geo+json',
#      'title': 'Sample Point Set'}},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-70.297866, 42.124461],
#       [-70.546477, 42.179218],
#       [-70.546367, 42.171619],
#       [-70.545793, 42.129884],
#       [-70.545227, 42.088557],
#       [-70.544692, 42.047613],
#       [-70.544175, 42.006997],
#       [-70.54368, 41.966781],
#       [-70.543193, 41.92692],
#       [-70.542449, 41.887238],
#       [-70.54198, 41.847983],
#       [-70.541709, 41.821517],
#       [-70.302305, 41.779481],
#       [-70.301853, 41.811082],
#       [-70.301631, 41.830873],
#       [-70.301392, 41.855185],
#       [-70.301325, 41.861559],
#       [-70.301145, 41.881088],
#       [-70.30102, 41.890426],
#       [-70.300987, 41.893534],
#       [-70.300629, 41.919581],
#       [-70.300266, 41.947131],
#       [-70.299959, 41.971084],
#       [-70.299631, 41.994819],
#       [-70.299593, 41.997637],
#       [-70.299168, 42.02911],
#       [-70.298891, 42.050044],
#       [-70.298736, 42.061438],
#       [-70.298528, 42.077048],
#       [-70.298346, 42.090055],
#       [-70.297967, 42.117311],
#       [-70.297866, 42.124461]]]},
#    'collection': 'wv03-vnir',
#    'properties': {'gsd': 0.467621232,
#     'title': 'Maxar WV03 Image 1040010093467000',
#     'datetime': '2024-03-01T15:16:41.400194Z',
#     'eo:bands': [{'name': 'pan', 'center_wavelength': 625},
#      {'name': 'nir2', 'center_wavelength': 948},
#      {'name': 'nir1', 'center_wavelength': 832},
#      {'name': 'red_edge', 'center_wavelength': 723.5},
#      {'name': 'red', 'center_wavelength': 661},
#      {'name': 'yellow', 'center_wavelength': 531},
#      {'name': 'green', 'center_wavelength': 546.5},
#      {'name': 'blue', 'center_wavelength': 481},
#      {'name': 'coastal', 'center_wavelength': 425.5}],
#     'platform': 'worldview-03',
#     'instruments': ['VNIR'],
#     'associations': [],
#     'view:azimuth': 313.753252,
#     'constellation': 'maxar',
#     'off_nadir_avg': 36.8860366,
#     'off_nadir_end': 38.065987,
#     'off_nadir_max': 38.065987,
#     'off_nadir_min': 35.66526,
#     'rda_available': False,
#     'eo:cloud_cover': 43.40437049200857,
#     'scan_direction': 'reverse',
#     'view:off_nadir': 36.8860366,
#     'off_nadir_start': 35.66526,
#     'collect_time_end': '2024-03-01T15:16:46.162530Z',
#     'view:sun_azimuth': 149.63697,
#     'raw_archive_state': 'online',
#     'collect_time_start': '2024-03-01T15:16:41.400194Z',
#     'pan_resolution_avg': 0.467621232,
#     'pan_resolution_end': 0.48435506,
#     'pan_resolution_max': 0.48435506,
#     'pan_resolution_min': 0.45178908,
#     'view:sun_elevation': 36.1737798,
#     'multi_resolution_avg': 1.80441926,
#     'multi_resolution_end': 1.8106198,
#     'multi_resolution_max': 1.8179177,
#     'multi_resolution_min': 1.7934142,
#     'pan_resolution_start': 0.45178908,
#     'acquisition_rev_number': 51765,
#     'multi_resolution_start': 1.8179177,
#     'view:sun_elevation_max': 36.3368,
#     'view:sun_elevation_min': 36.018597,
#     'geolocation_uncertainty': 4.163631026347948,
#     'stereo_pair_identifiers': [],
#     'spacecraft_to_target_azimuth_avg': 313.753252,
#     'spacecraft_to_target_azimuth_end': 317.14462,
#     'spacecraft_to_target_azimuth_max': 317.14462,
#     'spacecraft_to_target_azimuth_min': 309.9591,
#     'target_to_spacecraft_azimuth_avg': 131.23071622671074,
#     'target_to_spacecraft_azimuth_end': 134.63123650826978,
#     'target_to_spacecraft_azimuth_max': 134.63123650826978,
#     'target_to_spacecraft_azimuth_min': 127.4269299802148,
#     'spacecraft_to_target_azimuth_start': 309.9591,
#     'target_to_spacecraft_azimuth_start': 127.4269299802148,
#     'target_to_spacecraft_elevation_avg': 48.692771439995674,
#     'target_to_spacecraft_elevation_end': 47.30582661512838,
#     'target_to_spacecraft_elevation_max': 50.1243023839592,
#     'target_to_spacecraft_elevation_min': 47.30582661512838,
#     'target_to_spacecraft_elevation_start': 50.1243023839592},
#    'stac_version': '1.0.0',
#    'stac_extensions': ['https://stac-extensions.github.io/eo/v1.0.0/schema.json',
#     'https://stac-extensions.github.io/view/v1.0.0/schema.json']},
#   {'id': '1040010093847B00',
#    'bbox': [-70.327463, 41.787511, -70.092543, 42.154854],
#    'type': 'Feature',
#    'links': [{'rel': 'collection',
#      'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir'},
#     {'rel': 'self',
#      'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/1040010093847B00'},
#     {'rel': 'root', 'href': 'https://api.maxar.com/discovery/v1/'},
#     {'rel': 'order-map-ready',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/map-ready/order',
#      'type': 'application/json'},
#     {'rel': 'order-system-ready',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/system-ready/order',
#      'type': 'application/json'},
#     {'rel': 'order-view-ready',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/view-ready/order',
#      'type': 'application/json'},
#     {'rel': 'order-view-ready-ortho',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/view-ready-ortho/order',
#      'type': 'application/json'}],
#    'assets': {'browse': {'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/1040010093847B00/assets/collections/dg-archive/assets/browse/1040010093847B00.browse.tif',
#      'type': 'image/tiff; application=geotiff',
#      'title': 'Browse Image'},
#     'cloud-cover': {'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/1040010093847B00/assets/collections/wv03-vnir/assets/cloud-cover/1040010093847B00.cloud.json',
#      'type': 'application/geo+json',
#      'title': 'Cloud Cover'},
#     'sample-point-set': {'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/1040010093847B00/assets/collections/wv03-vnir/assets/sample-point-sets/1040010093847B00.sample-points.json',
#      'type': 'application/geo+json',
#      'title': 'Sample Point Set'}},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-70.327463, 42.154854],
#       [-70.327239, 42.118216],
#       [-70.327003, 42.081621],
#       [-70.326796, 42.045054],
#       [-70.326585, 42.008527],
#       [-70.326363, 41.972031],
#       [-70.32614, 41.935567],
#       [-70.325917, 41.89913],
#       [-70.325681, 41.862727],
#       [-70.325454, 41.826346],
#       [-70.325424, 41.820916],
#       [-70.094402, 41.787511],
#       [-70.094369, 41.793164],
#       [-70.094175, 41.829388],
#       [-70.09399, 41.865633],
#       [-70.09379, 41.901911],
#       [-70.093589, 41.938215],
#       [-70.093377, 41.974547],
#       [-70.093161, 42.010912],
#       [-70.092827, 42.04726],
#       [-70.092744, 42.083748],
#       [-70.092543, 42.120226],
#       [-70.327463, 42.154854]]]},
#    'collection': 'wv03-vnir',
#    'properties': {'gsd': 0.433713612,
#     'title': 'Maxar WV03 Image 1040010093847B00',
#     'datetime': '2024-03-01T15:16:29.700217Z',
#     'eo:bands': [{'name': 'pan', 'center_wavelength': 625},
#      {'name': 'nir2', 'center_wavelength': 948},
#      {'name': 'nir1', 'center_wavelength': 832},
#      {'name': 'red_edge', 'center_wavelength': 723.5},
#      {'name': 'red', 'center_wavelength': 661},
#      {'name': 'yellow', 'center_wavelength': 531},
#      {'name': 'green', 'center_wavelength': 546.5},
#      {'name': 'blue', 'center_wavelength': 481},
#      {'name': 'coastal', 'center_wavelength': 425.5}],
#     'platform': 'worldview-03',
#     'instruments': ['VNIR'],
#     'associations': [],
#     'view:azimuth': 305.946606,
#     'constellation': 'maxar',
#     'off_nadir_avg': 33.9244914,
#     'off_nadir_end': 33.685867,
#     'off_nadir_max': 34.187893,
#     'off_nadir_min': 33.685867,
#     'rda_available': False,
#     'eo:cloud_cover': 28.47656281128326,
#     'scan_direction': 'forward',
#     'view:off_nadir': 33.9244914,
#     'off_nadir_start': 34.187893,
#     'collect_time_end': '2024-03-01T15:16:34.609755Z',
#     'view:sun_azimuth': 149.815858,
#     'raw_archive_state': 'online',
#     'collect_time_start': '2024-03-01T15:16:29.700217Z',
#     'pan_resolution_avg': 0.433713612,
#     'pan_resolution_end': 0.4312618,
#     'pan_resolution_max': 0.4364092,
#     'pan_resolution_min': 0.4312618,
#     'view:sun_elevation': 36.2528572,
#     'multi_resolution_avg': 1.734315,
#     'multi_resolution_end': 1.7245237,
#     'multi_resolution_max': 1.7450801,
#     'multi_resolution_min': 1.7245237,
#     'pan_resolution_start': 0.4364092,
#     'acquisition_rev_number': 51765,
#     'multi_resolution_start': 1.7450801,
#     'view:sun_elevation_max': 36.403244,
#     'view:sun_elevation_min': 36.086647,
#     'geolocation_uncertainty': 25.06056,
#     'stereo_pair_identifiers': [],
#     'spacecraft_to_target_azimuth_avg': 305.946606,
#     'spacecraft_to_target_azimuth_end': 305.80612,
#     'spacecraft_to_target_azimuth_max': 306.10617,
#     'spacecraft_to_target_azimuth_min': 305.80612,
#     'target_to_spacecraft_azimuth_avg': 125.9466064453125,
#     'target_to_spacecraft_azimuth_end': 125.80612182617188,
#     'target_to_spacecraft_azimuth_max': 126.10617065429688,
#     'target_to_spacecraft_azimuth_min': 125.80612182617188,
#     'spacecraft_to_target_azimuth_start': 306.10617,
#     'target_to_spacecraft_azimuth_start': 126.10617065429688,
#     'target_to_spacecraft_elevation_avg': 52.25926020131679,
#     'target_to_spacecraft_elevation_end': 52.53380979405533,
#     'target_to_spacecraft_elevation_max': 52.53380979405533,
#     'target_to_spacecraft_elevation_min': 51.956047766356434,
#     'target_to_spacecraft_elevation_start': 51.956047766356434},
#    'stac_version': '1.0.0',
#    'stac_extensions': ['https://stac-extensions.github.io/eo/v1.0.0/schema.json',
#     'https://stac-extensions.github.io/view/v1.0.0/schema.json']},
#   {'id': '1040010092BD6D00',
#    'bbox': [-70.244082, 41.776935, -69.996287, 42.183122],
#    'type': 'Feature',
#    'links': [{'rel': 'collection',
#      'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir'},
#     {'rel': 'self',
#      'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/1040010092BD6D00'},
#     {'rel': 'root', 'href': 'https://api.maxar.com/discovery/v1/'},
#     {'rel': 'order-map-ready',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/map-ready/order',
#      'type': 'application/json'},
#     {'rel': 'order-system-ready',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/system-ready/order',
#      'type': 'application/json'},
#     {'rel': 'order-view-ready',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/view-ready/order',
#      'type': 'application/json'},
#     {'rel': 'order-view-ready-ortho',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/view-ready-ortho/order',
#      'type': 'application/json'}],
#    'assets': {'browse': {'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/1040010092BD6D00/assets/collections/dg-archive/assets/browse/1040010092BD6D00.browse.tif',
#      'type': 'image/tiff; application=geotiff',
#      'title': 'Browse Image'},
#     'cloud-cover': {'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/1040010092BD6D00/assets/collections/wv03-vnir/assets/cloud-cover/1040010092BD6D00.cloud.json',
#      'type': 'application/geo+json',
#      'title': 'Cloud Cover'},
#     'sample-point-set': {'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/1040010092BD6D00/assets/collections/wv03-vnir/assets/sample-point-sets/1040010092BD6D00.sample-points.json',
#      'type': 'application/geo+json',
#      'title': 'Sample Point Set'}},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-69.996287, 42.125762],
#       [-70.244082, 42.183122],
#       [-70.244028, 42.179513],
#       [-70.243405, 42.136739],
#       [-70.242884, 42.09446],
#       [-70.242238, 42.052504],
#       [-70.241676, 42.01095],
#       [-70.241149, 41.969837],
#       [-70.240631, 41.929098],
#       [-70.240127, 41.888761],
#       [-70.239621, 41.84884],
#       [-70.239276, 41.821705],
#       [-70.000976, 41.776935],
#       [-70.000771, 41.803077],
#       [-70.000635, 41.812842],
#       [-70.000612, 41.815565],
#       [-70.000204, 41.844011],
#       [-69.999731, 41.880634],
#       [-69.999697, 41.882778],
#       [-69.999563, 41.893345],
#       [-69.999057, 41.9231],
#       [-69.998796, 41.941416],
#       [-69.998446, 41.972664],
#       [-69.997946, 42.012941],
#       [-69.997809, 42.022753],
#       [-69.997585, 42.040369],
#       [-69.997404, 42.05164],
#       [-69.997377, 42.053556],
#       [-69.996816, 42.088994],
#       [-69.996333, 42.122457],
#       [-69.996287, 42.125762]]]},
#    'collection': 'wv03-vnir',
#    'properties': {'gsd': 0.472381162,
#     'title': 'Maxar WV03 Image 1040010092BD6D00',
#     'datetime': '2024-02-11T15:16:03.168665Z',
#     'eo:bands': [{'name': 'pan', 'center_wavelength': 625},
#      {'name': 'nir2', 'center_wavelength': 948},
#      {'name': 'nir1', 'center_wavelength': 832},
#      {'name': 'red_edge', 'center_wavelength': 723.5},
#      {'name': 'red', 'center_wavelength': 661},
#      {'name': 'yellow', 'center_wavelength': 531},
#      {'name': 'green', 'center_wavelength': 546.5},
#      {'name': 'blue', 'center_wavelength': 481},
#      {'name': 'coastal', 'center_wavelength': 425.5}],
#     'platform': 'worldview-03',
#     'instruments': ['VNIR'],
#     'associations': [],
#     'view:azimuth': 316.619912,
#     'constellation': 'maxar',
#     'off_nadir_avg': 37.2093484,
#     'off_nadir_end': 38.454407,
#     'off_nadir_max': 38.454407,
#     'off_nadir_min': 35.90987,
#     'rda_available': False,
#     'eo:cloud_cover': 66.07350329590946,
#     'scan_direction': 'reverse',
#     'view:off_nadir': 37.2093484,
#     'off_nadir_start': 35.90987,
#     'collect_time_end': '2024-02-11T15:16:07.882198Z',
#     'view:sun_azimuth': 152.239106,
#     'raw_archive_state': 'online',
#     'collect_time_start': '2024-02-11T15:16:03.168665Z',
#     'pan_resolution_avg': 0.472381162,
#     'pan_resolution_end': 0.48892692,
#     'pan_resolution_max': 0.48892692,
#     'pan_resolution_min': 0.45614797,
#     'view:sun_elevation': 29.7098006,
#     'multi_resolution_avg': 1.81222288,
#     'multi_resolution_end': 1.8260059,
#     'multi_resolution_max': 1.8260059,
#     'multi_resolution_min': 1.7972687,
#     'pan_resolution_start': 0.45614797,
#     'acquisition_rev_number': 51483,
#     'multi_resolution_start': 1.7972687,
#     'view:sun_elevation_max': 29.879393,
#     'view:sun_elevation_min': 29.548332,
#     'geolocation_uncertainty': 3.379968521784232,
#     'stereo_pair_identifiers': [],
#     'spacecraft_to_target_azimuth_avg': 316.619912,
#     'spacecraft_to_target_azimuth_end': 319.8347,
#     'spacecraft_to_target_azimuth_max': 319.8347,
#     'spacecraft_to_target_azimuth_min': 313.01212,
#     'target_to_spacecraft_azimuth_avg': 134.1915545614596,
#     'target_to_spacecraft_azimuth_end': 137.41518024784546,
#     'target_to_spacecraft_azimuth_max': 137.41518024784546,
#     'target_to_spacecraft_azimuth_min': 130.57465416356754,
#     'spacecraft_to_target_azimuth_start': 313.01212,
#     'target_to_spacecraft_azimuth_start': 130.57465416356754,
#     'target_to_spacecraft_elevation_avg': 48.30562709784697,
#     'target_to_spacecraft_elevation_end': 46.84097350385865,
#     'target_to_spacecraft_elevation_max': 49.830069140156375,
#     'target_to_spacecraft_elevation_min': 46.84097350385865,
#     'target_to_spacecraft_elevation_start': 49.830069140156375},
#    'stac_version': '1.0.0',
#    'stac_extensions': ['https://stac-extensions.github.io/eo/v1.0.0/schema.json',
#     'https://stac-extensions.github.io/view/v1.0.0/schema.json']},
#   {'id': '10400100928B3000',
#    'bbox': [-70.337687, 41.78186, -70.11141, 42.170101],
#    'type': 'Feature',
#    'links': [{'rel': 'collection',
#      'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir'},
#     {'rel': 'self',
#      'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/10400100928B3000'},
#     {'rel': 'root', 'href': 'https://api.maxar.com/discovery/v1/'},
#     {'rel': 'order-map-ready',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/map-ready/order',
#      'type': 'application/json'},
#     {'rel': 'order-system-ready',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/system-ready/order',
#      'type': 'application/json'},
#     {'rel': 'order-view-ready',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/view-ready/order',
#      'type': 'application/json'},
#     {'rel': 'order-view-ready-ortho',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/view-ready-ortho/order',
#      'type': 'application/json'}],
#    'assets': {'browse': {'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/10400100928B3000/assets/collections/dg-archive/assets/browse/10400100928B3000.browse.tif',
#      'type': 'image/tiff; application=geotiff',
#      'title': 'Browse Image'},
#     'cloud-cover': {'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/10400100928B3000/assets/collections/wv03-vnir/assets/cloud-cover/10400100928B3000.cloud.json',
#      'type': 'application/geo+json',
#      'title': 'Cloud Cover'},
#     'sample-point-set': {'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/10400100928B3000/assets/collections/wv03-vnir/assets/sample-point-sets/10400100928B3000.sample-points.json',
#      'type': 'application/geo+json',
#      'title': 'Sample Point Set'}},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-70.11141, 42.120841],
#       [-70.337687, 42.170101],
#       [-70.337355, 42.148766],
#       [-70.336689, 42.104473],
#       [-70.336081, 42.060752],
#       [-70.335372, 42.017438],
#       [-70.334705, 41.974699],
#       [-70.334068, 41.932489],
#       [-70.333526, 41.890799],
#       [-70.332895, 41.849545],
#       [-70.332444, 41.821668],
#       [-70.116383, 41.78186],
#       [-70.116064, 41.808886],
#       [-70.116048, 41.810053],
# ...
#     'view:sun_azimuth': 152.995452881,
#     'raw_archive_state': 'offline',
#     'collect_time_start': '2015-03-16T15:32:45.032137Z',
#     'pan_resolution_avg': 0.3166911304,
#     'pan_resolution_end': 0.315185874701,
#     'pan_resolution_max': 0.318408489227,
#     'pan_resolution_min': 0.315185874701,
#     'view:sun_elevation': 43.48072052,
#     'multi_resolution_avg': 1.2669261694,
#     'multi_resolution_end': 1.26088166237,
#     'multi_resolution_max': 1.27395021915,
#     'multi_resolution_min': 1.26088166237,
#     'pan_resolution_start': 0.318408489227,
#     'acquisition_rev_number': 3190,
#     'multi_resolution_start': 1.27395021915,
#     'view:sun_elevation_max': 43.8495101929,
#     'view:sun_elevation_min': 43.041267395,
#     'geolocation_uncertainty': 17.9745082855,
#     'stereo_pair_identifiers': [],
#     'spacecraft_to_target_azimuth_avg': 259.341339111,
#     'spacecraft_to_target_azimuth_end': 260.106262207,
#     'spacecraft_to_target_azimuth_max': 260.106262207,
#     'spacecraft_to_target_azimuth_min': 258.623413086,
#     'target_to_spacecraft_azimuth_avg': 79.34134589300001,
#     'target_to_spacecraft_azimuth_end': 80.10626220699999,
#     'target_to_spacecraft_azimuth_max': 80.10626220699999,
#     'target_to_spacecraft_azimuth_min': 78.62341308600003,
#     'spacecraft_to_target_azimuth_start': 258.623413086,
#     'target_to_spacecraft_azimuth_start': 78.62341308600003,
#     'target_to_spacecraft_elevation_avg': 80.06799173755425,
#     'target_to_spacecraft_elevation_end': 81.19689878434703,
#     'target_to_spacecraft_elevation_max': 81.19689878434703,
#     'target_to_spacecraft_elevation_min': 78.73535221831969,
#     'target_to_spacecraft_elevation_start': 78.73535221831969},
#    'stac_version': '1.0.0',
#    'stac_extensions': ['https://stac-extensions.github.io/eo/v1.0.0/schema.json',
#     'https://stac-extensions.github.io/view/v1.0.0/schema.json']},
#   {'id': '1040010009A2C200',
#    'bbox': [-70.249351, 41.195575, -70.0689, 42.076729],
#    'type': 'Feature',
#    'links': [{'rel': 'collection',
#      'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir'},
#     {'rel': 'self',
#      'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/1040010009A2C200'},
#     {'rel': 'root', 'href': 'https://api.maxar.com/discovery/v1/'},
#     {'rel': 'order-map-ready',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/map-ready/order',
#      'type': 'application/json'},
#     {'rel': 'order-system-ready',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/system-ready/order',
#      'type': 'application/json'},
#     {'rel': 'order-view-ready',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/view-ready/order',
#      'type': 'application/json'},
#     {'rel': 'order-view-ready-ortho',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/view-ready-ortho/order',
#      'type': 'application/json'}],
#    'assets': {'browse': {'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/1040010009A2C200/assets/collections/dg-archive/assets/browse/1040010009A2C200.browse.tif',
#      'type': 'image/tiff; application=geotiff',
#      'title': 'Browse Image'},
#     'cloud-cover': {'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/1040010009A2C200/assets/collections/wv03-vnir/assets/cloud-cover/1040010009A2C200.cloud.json',
#      'type': 'application/geo+json',
#      'title': 'Cloud Cover'},
#     'sample-point-set': {'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/1040010009A2C200/assets/collections/wv03-vnir/assets/sample-point-sets/1040010009A2C200.sample-points.json',
#      'type': 'application/geo+json',
#      'title': 'Sample Point Set'}},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-70.0689, 41.210009],
#       [-70.069294, 41.243952],
#       [-70.069644, 41.277632],
#       [-70.070009, 41.310938],
#       [-70.070354, 41.343994],
#       [-70.070676, 41.376752],
#       [-70.071003, 41.409239],
#       [-70.071305, 41.441491],
#       [-70.071612, 41.473477],
#       [-70.07191, 41.505214],
#       [-70.072194, 41.536706],
#       [-70.072476, 41.567993],
#       [-70.072743, 41.599059],
#       [-70.072988, 41.629925],
#       [-70.073224, 41.660591],
#       [-70.073425, 41.691109],
#       [-70.073655, 41.721398],
#       [-70.073821, 41.751556],
#       [-70.074098, 41.781427],
#       [-70.074299, 41.811227],
#       [-70.074485, 41.840856],
#       [-70.074661, 41.870342],
#       [-70.074821, 41.899694],
#       [-70.074973, 41.928948],
#       [-70.075117, 41.958061],
#       [-70.07525, 41.987048],
#       [-70.075343, 42.015964],
#       [-70.075464, 42.044746],
#       [-70.075613, 42.073434],
#       [-70.075625, 42.076729],
#       [-70.241831, 42.073819],
#       [-70.241843, 42.070362],
#       [-70.241971, 42.041351],
#       [-70.242114, 42.012256],
#       [-70.242257, 41.983053],
#       [-70.242425, 41.953745],
#       [-70.24259, 41.92431],
#       [-70.24277, 41.894728],
#       [-70.242964, 41.865041],
#       [-70.243163, 41.83521],
#       [-70.243373, 41.805228],
#       [-70.243587, 41.775069],
#       [-70.243825, 41.744753],
#       [-70.244068, 41.714265],
#       [-70.244263, 41.68364],
#       [-70.24456, 41.652733],
#       [-70.244859, 41.621649],
#       [-70.245151, 41.590372],
#       [-70.245441, 41.558887],
#       [-70.245736, 41.527171],
#       [-70.24605, 41.49524],
#       [-70.24637, 41.463054],
#       [-70.246701, 41.430607],
#       [-70.247059, 41.397884],
#       [-70.247415, 41.364913],
#       [-70.247791, 41.331663],
#       [-70.24817, 41.298098],
#       [-70.24858, 41.264224],
#       [-70.248959, 41.230063],
#       [-70.249351, 41.195575],
#       [-70.0689, 41.210009]]]},
#    'collection': 'wv03-vnir',
#    'properties': {'gsd': 0.340363800526,
#     'title': 'Maxar WV03 Image 1040010009A2C200',
#     'datetime': '2015-03-16T15:32:23.532990Z',
#     'eo:bands': [{'name': 'pan', 'center_wavelength': 625},
#      {'name': 'nir2', 'center_wavelength': 948},
#      {'name': 'nir1', 'center_wavelength': 832},
#      {'name': 'red_edge', 'center_wavelength': 723.5},
#      {'name': 'red', 'center_wavelength': 661},
#      {'name': 'yellow', 'center_wavelength': 531},
#      {'name': 'green', 'center_wavelength': 546.5},
#      {'name': 'blue', 'center_wavelength': 481},
#      {'name': 'coastal', 'center_wavelength': 425.5}],
#     'platform': 'worldview-03',
#     'instruments': ['VNIR'],
#     'associations': [],
#     'view:azimuth': 220.155838013,
#     'constellation': 'maxar',
#     'off_nadir_avg': 17.9961185455,
#     'off_nadir_end': 11.8928775787,
#     'off_nadir_max': 25.5362911224,
#     'off_nadir_min': 11.8928775787,
#     'rda_available': False,
#     'eo:cloud_cover': 0.0,
#     'scan_direction': 'reverse',
#     'view:off_nadir': 17.9961185455,
#     'off_nadir_start': 25.5362911224,
#     'collect_time_end': '2015-03-16T15:32:37.924897Z',
#     'view:sun_azimuth': 153.088928223,
#     'raw_archive_state': 'offline',
#     'collect_time_start': '2015-03-16T15:32:23.532990Z',
#     'pan_resolution_avg': 0.340363800526,
#     'pan_resolution_end': 0.321663439274,
#     'pan_resolution_max': 0.370613753796,
#     'pan_resolution_min': 0.321663439274,
#     'view:sun_elevation': 43.4267349243,
#     'multi_resolution_avg': 1.36270332336,
#     'multi_resolution_end': 1.2872800827,
#     'multi_resolution_max': 1.48470032215,
#     'multi_resolution_min': 1.2872800827,
#     'pan_resolution_start': 0.370613753796,
#     'acquisition_rev_number': 3190,
#     'multi_resolution_start': 1.48470032215,
#     'view:sun_elevation_max': 43.8535346985,
#     'view:sun_elevation_min': 43.0782279968,
#     'geolocation_uncertainty': 19.2566280365,
#     'stereo_pair_identifiers': [],
#     'spacecraft_to_target_azimuth_avg': 220.155838013,
#     'spacecraft_to_target_azimuth_end': 237.50289917,
#     'spacecraft_to_target_azimuth_max': 237.50289917,
#     'spacecraft_to_target_azimuth_min': 207.093597412,
#     'target_to_spacecraft_azimuth_avg': 40.185312907,
#     'target_to_spacecraft_azimuth_end': 57.50289916999998,
#     'target_to_spacecraft_azimuth_max': 57.50289916999998,
#     'target_to_spacecraft_azimuth_min': 27.09359741200001,
#     'spacecraft_to_target_azimuth_start': 207.093597412,
#     'target_to_spacecraft_azimuth_start': 27.09359741200001,
#     'target_to_spacecraft_elevation_avg': 70.1786984198769,
#     'target_to_spacecraft_elevation_end': 76.93723530325924,
#     'target_to_spacecraft_elevation_max': 76.93723530325924,
#     'target_to_spacecraft_elevation_min': 61.784820685799545,
#     'target_to_spacecraft_elevation_start': 61.784820685799545},
#    'stac_version': '1.0.0',
#    'stac_extensions': ['https://stac-extensions.github.io/eo/v1.0.0/schema.json',
#     'https://stac-extensions.github.io/view/v1.0.0/schema.json']},
#   {'id': '1040010002A99600',
#    'bbox': [-70.66926, 41.96943, -70.492895, 43.014569],
#    'type': 'Feature',
#    'links': [{'rel': 'collection',
#      'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir'},
#     {'rel': 'self',
#      'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/1040010002A99600'},
#     {'rel': 'root', 'href': 'https://api.maxar.com/discovery/v1/'},
#     {'rel': 'order-map-ready',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/map-ready/order',
#      'type': 'application/json'},
#     {'rel': 'order-system-ready',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/system-ready/order',
#      'type': 'application/json'},
#     {'rel': 'order-view-ready',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/view-ready/order',
#      'type': 'application/json'},
#     {'rel': 'order-view-ready-ortho',
#      'href': 'https://api.maxar.com/ordering/v1/pipelines/imagery/view-ready-ortho/order',
#      'type': 'application/json'}],
#    'assets': {'browse': {'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/1040010002A99600/assets/collections/dg-archive/assets/browse/1040010002A99600.browse.tif',
#      'type': 'image/tiff; application=geotiff',
#      'title': 'Browse Image'},
#     'cloud-cover': {'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/1040010002A99600/assets/collections/wv03-vnir/assets/cloud-cover/1040010002A99600.cloud.json',
#      'type': 'application/geo+json',
#      'title': 'Cloud Cover'},
#     'sample-point-set': {'href': 'https://api.maxar.com/discovery/v1/collections/wv03-vnir/items/1040010002A99600/assets/collections/wv03-vnir/assets/sample-point-sets/1040010002A99600.sample-points.json',
#      'type': 'application/geo+json',
#      'title': 'Sample Point Set'}},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-70.66926, 43.010688],
#       [-70.669141, 42.981439],
#       [-70.669038, 42.95221],
#       [-70.668926, 42.922993],
#       [-70.668807, 42.893788],
#       [-70.668695, 42.864595],
#       [-70.668573, 42.835415],
#       [-70.668466, 42.806244],
#       [-70.668371, 42.777079],
#       [-70.668259, 42.747922],
#       [-70.668146, 42.718776],
#       [-70.668045, 42.689644],
#       [-70.667859, 42.660552],
#       [-70.667771, 42.631443],
#       [-70.667761, 42.602317],
#       [-70.667644, 42.573228],
#       [-70.667545, 42.544148],
#       [-70.667446, 42.51508],
#       [-70.667345, 42.486029],
#       [-70.667257, 42.456992],
#       [-70.667155, 42.427957],
#       [-70.667052, 42.398929],
#       [-70.666941, 42.369912],
#       [-70.66682, 42.340912],
#       [-70.666712, 42.31192],
#       [-70.666617, 42.282938],
#       [-70.666526, 42.253965],
#       [-70.666433, 42.225001],
#       [-70.66634, 42.196058],
#       [-70.666245, 42.167121],
#       [-70.666144, 42.138185],
#       [-70.666019, 42.109269],
#       [-70.665903, 42.080369],
#       [-70.665827, 42.051464],
#       [-70.665734, 42.022574],
#       [-70.665636, 41.993691],
#       [-70.665553, 41.96943],
#       [-70.496322, 41.972268],
#       [-70.496246, 41.996655],
#       [-70.496161, 42.025563],
#       [-70.49608, 42.054475],
#       [-70.495985, 42.083401],
#       [-70.495897, 42.112332],
#       [-70.495815, 42.141278],
#       [-70.495726, 42.17024],
#       [-70.495629, 42.199203],
#       [-70.495531, 42.228172],
#       [-70.495431, 42.257162],
#       [-70.495329, 42.28616],
#       [-70.49523, 42.315168],
#       [-70.495143, 42.344187],
#       [-70.495069, 42.373213],
#       [-70.494983, 42.402256],
#       [-70.494888, 42.43131],
#       [-70.494793, 42.460371],
#       [-70.494682, 42.489435],
#       [-70.494585, 42.518512],
#       [-70.494484, 42.547605],
#       [-70.494382, 42.576712],
#       [-70.494298, 42.605827],
#       [-70.494197, 42.634956],
#       [-70.494085, 42.66409],
#       [-70.493973, 42.693234],
#       [-70.49387, 42.722392],
#       [-70.493777, 42.751564],
#       [-70.493683, 42.780748],
#       [-70.493571, 42.809939],
#       [-70.493471, 42.839136],
#       [-70.493384, 42.868343],
#       [-70.493287, 42.897563],
#       [-70.493196, 42.926794],
#       [-70.493097, 42.956038],
#       [-70.492989, 42.985294],
#       [-70.492895, 43.014569],
#       [-70.66926, 43.010688]]]},
#    'collection': 'wv03-vnir',
#    'properties': {'gsd': 0.328525453806,
#     'title': 'Maxar WV03 Image 1040010002A99600',
#     'datetime': '2014-10-09T15:22:40.378805Z',
#     'eo:bands': [{'name': 'pan', 'center_wavelength': 625},
#      {'name': 'nir2', 'center_wavelength': 948},
#      {'name': 'nir1', 'center_wavelength': 832},
#      {'name': 'red_edge', 'center_wavelength': 723.5},
#      {'name': 'red', 'center_wavelength': 661},
#      {'name': 'yellow', 'center_wavelength': 531},
#      {'name': 'green', 'center_wavelength': 546.5},
#      {'name': 'blue', 'center_wavelength': 481},
#      {'name': 'coastal', 'center_wavelength': 425.5}],
#     'platform': 'worldview-03',
#     'instruments': ['VNIR'],
#     'associations': [],
#     'view:azimuth': 250.543716431,
#     'constellation': 'maxar',
#     'off_nadir_avg': 15.0094957352,
#     'off_nadir_end': 13.8727626801,
#     'off_nadir_max': 16.2289714813,
#     'off_nadir_min': 13.8727626801,
#     'rda_available': False,
#     'eo:cloud_cover': 0.007944210915345798,
#     'scan_direction': 'forward',
#     'view:off_nadir': 15.0094957352,
#     'off_nadir_start': 16.2289714813,
#     'collect_time_end': '2014-10-09T15:22:58.633099Z',
#     'view:sun_azimuth': 158.460647583,
#     'raw_archive_state': 'offline',
#     'collect_time_start': '2014-10-09T15:22:40.378805Z',
#     'pan_resolution_avg': 0.328525453806,
#     'pan_resolution_end': 0.325529336929,
#     'pan_resolution_max': 0.331929117441,
#     'pan_resolution_min': 0.325529336929,
#     'view:sun_elevation': 39.0109062195,
#     'multi_resolution_avg': 1.31431019306,
#     'multi_resolution_end': 1.30231738091,
#     'multi_resolution_max': 1.32793390751,
#     'multi_resolution_min': 1.30231738091,
#     'pan_resolution_start': 0.331929117441,
#     'acquisition_rev_number': 845,
#     'multi_resolution_start': 1.32793390751,
#     'view:sun_elevation_max': 39.4917182922,
#     'view:sun_elevation_min': 38.4846229553,
#     'geolocation_uncertainty': 18.6804866791,
#     'stereo_pair_identifiers': [],
#     'spacecraft_to_target_azimuth_avg': 250.543716431,
#     'spacecraft_to_target_azimuth_end': 249.79083252,
#     'spacecraft_to_target_azimuth_max': 251.370956421,
#     'spacecraft_to_target_azimuth_min': 249.79083252,
#     'target_to_spacecraft_azimuth_avg': 70.54372406009999,
#     'target_to_spacecraft_azimuth_end': 69.79083251999998,
#     'target_to_spacecraft_azimuth_max': 71.37095642099996,
#     'target_to_spacecraft_azimuth_min': 69.79083251999998,
#     'spacecraft_to_target_azimuth_start': 251.370956421,
#     'target_to_spacecraft_azimuth_start': 71.37095642099996,
#     'target_to_spacecraft_elevation_avg': 73.49869256721608,
#     'target_to_spacecraft_elevation_end': 74.75418264487084,
#     'target_to_spacecraft_elevation_max': 74.75418264487084,
#     'target_to_spacecraft_elevation_min': 72.15082983599562,
#     'target_to_spacecraft_elevation_start': 72.15082983599562},
#    'stac_version': '1.0.0',
#    'stac_extensions': ['https://stac-extensions.github.io/eo/v1.0.0/schema.json',
#     'https://stac-extensions.github.io/view/v1.0.0/schema.json']}],
#  'numberReturned': 168,
#  'timestamp': '2024-08-14T17:58:47.142863Z',
#  'links': [{'rel': 'root', 'href': 'https://api.maxar.com/discovery/v1/'}]}

# %% [markdown]
# ### Create a GeoDataFrame from query results

# %%
columns = ["id", "platform", "instruments", "gsd", "pan_resolution_avg",
           "multi_resolution_avg", "datetime", "off_nadir", "azimuth",
           "sun_azimuth", "sun_elevation", "bbox"]
gdf = gpd.GeoDataFrame(columns = columns)
gdf = gdf.set_geometry("bbox").set_crs("EPSG:4326")

r = response.json()
for i, feature in enumerate(r["features"]):
    gdf.loc[i, "id"] = feature["id"]
    gdf.loc[i, "aoi_id"] = aoi_id
    gdf.loc[i, "platform"] = feature["properties"]["platform"]
    gdf.loc[i, "instruments"] = ', '.join(feature["properties"]["instruments"])
    gdf.loc[i, "gsd"] = feature["properties"]["gsd"]
    gdf.loc[i, "pan_resolution_avg"] = feature["properties"]["pan_resolution_avg"]
    gdf.loc[i, "multi_resolution_avg"] = feature["properties"]["multi_resolution_avg"]
    gdf.loc[i, "datetime"] = feature["properties"]["datetime"]
    gdf.loc[i, "off_nadir"] = feature["properties"]["view:off_nadir"]
    gdf.loc[i, "azimuth"] = feature["properties"]["view:azimuth"]
    gdf.loc[i, "sun_azimuth"] = feature["properties"]["view:sun_azimuth"]
    gdf.loc[i, "sun_elevation"] = feature["properties"]["view:sun_elevation"]
    gdf.loc[i, "bbox"] = box(*feature["bbox"])

gdf.head()
# Out:
#                  id      platform instruments       gsd pan_resolution_avg  \
# 0  1040010093625500  worldview-03        VNIR   0.48959            0.48959
# 1  10400100959B5400  worldview-03        VNIR  0.465732           0.465732
# 2  1040010096672600  worldview-03        VNIR  0.387751           0.387751
# 3  1040010091057E00  worldview-03        VNIR  0.477092           0.477092
# 4  1040010093A5AA00  worldview-03        VNIR  0.400867           0.400867
#
#   multi_resolution_avg                     datetime  off_nadir     azimuth  \
# 0             1.957822  2024-05-10T15:12:09.830632Z  38.731296   298.21721
# 1             1.861867  2024-05-10T15:11:58.030657Z    36.9672  290.060698
# 2             1.566842  2024-05-04T15:18:49.787012Z  28.198752  300.877281
# 3             1.825612  2024-03-14T15:21:50.586824Z  37.508765  332.149348
# 4             1.545379  2024-03-14T15:21:27.286870Z  29.931199   320.08349
#
#   sun_azimuth sun_elevation  \
# 0   135.97089     59.840196
# 1   136.29946     59.933401
# 2  140.548459     59.617618
# 3  149.478354     41.594089
# 4  149.822968     41.697987
#
#                                                 bbox aoi_id
# 0  POLYGON ((-70.33367 41.78036, -70.33367 42.162...      6
# 1  POLYGON ((-70.09283 41.80274, -70.09283 42.154...      6
# 2  POLYGON ((-69.99209 41.46543, -69.99209 42.029...      6
# 3  POLYGON ((-70.44030 41.77703, -70.44030 42.178...      6
# 4  POLYGON ((-70.07881 41.79959, -70.07881 42.149...      6

# %%
gdf.shape
# Out:
# (168, 13)

# %% [markdown]
# ### Drop table
# This is for demonstration purposes

# %%
conn = sqlite3.connect(db)
conn.enable_load_extension(True)
conn.execute("SELECT load_extension('mod_spatialite')")

c = conn.cursor()
c.execute('''DROP TABLE IF EXISTS mgp''')
conn.commit()
conn.close()

# %% [markdown]
# ### Create `mgp` table

# %%
conn = sqlite3.connect(db)
conn.enable_load_extension(True)
conn.execute("SELECT load_extension('mod_spatialite')")

c = conn.cursor()

c.execute('''
    CREATE TABLE IF NOT EXISTS mgp(
        id VARCHAR(16) PRIMARY KEY,
        aoi_id VARCHAR(4),
        platform VARCHAR(11),
        instruments VARCHAR(4),
        gsd NUMERIC(2, 3),
        pan_resolution_avg NUMERIC(2, 3),
        multi_resolution_avg NUMERIC(2, 3),
        datetime DATETIME2,
        off_nadir NUMERIC(2, 3),
        azimuth NUMERIC(3, 3),
        sun_azimuth NUMERIC(3, 3),
        sun_elevation NUMERIC(3, 3),
        bbox POLYGON,
        FOREIGN KEY (aoi_id)
            REFERENCES aoi(id)
    )
''')

conn.commit()
conn.close()

# %% [markdown]
# ### Insert Maxar Geospatial Platform IDs into `mgp` table

# %%
conn = sqlite3.connect(db)
conn.enable_load_extension(True)
conn.execute("SELECT load_extension('mod_spatialite')")

c = conn.cursor()

for i, row in gdf.iterrows():
    try:
        insert_mgp(c, row['id'])
    except Exception as e:
        print("Exception: {} was raised for ID {}".format(e, row['id']))
print("Done inserting Imagery IDs into table!")
conn.commit()
conn.close()
# Out:
# Done inserting Imagery IDs into table!

# %% [markdown]
# ### Update `mgp` records from Maxar Geospatial Platform results

# %%
columns = gdf.columns[1:]
for i, row in gdf.iterrows():
    iid = row['id']
    print("Updating information for Imagery ID: {}".format(iid))
    for column in columns:
        database_activity(db, iid, column, row[column])
# Out:
# Updating information for Imagery ID: 1040010093625500
# Updating information for Imagery ID: 10400100959B5400
# Updating information for Imagery ID: 1040010096672600
# Updating information for Imagery ID: 1040010091057E00
# Updating information for Imagery ID: 1040010093A5AA00
# Updating information for Imagery ID: 1040010093467000
# Updating information for Imagery ID: 1040010093847B00
# Updating information for Imagery ID: 1040010092BD6D00
# Updating information for Imagery ID: 10400100928B3000
# Updating information for Imagery ID: 10400100915D6100
# Updating information for Imagery ID: 104001009037FF00
# Updating information for Imagery ID: 104001008D3FC800
# Updating information for Imagery ID: 104001009076F600
# Updating information for Imagery ID: 104001008C471A00
# Updating information for Imagery ID: 104001008D113000
# Updating information for Imagery ID: 104001008D95DA00
# Updating information for Imagery ID: 104001008C0F7C00
# Updating information for Imagery ID: 104001008DC4AA00
# Updating information for Imagery ID: 104001008B789100
# Updating information for Imagery ID: 104001008D203C00
# Updating information for Imagery ID: 104001008C164D00
# Updating information for Imagery ID: 104001008B104700
# Updating information for Imagery ID: 104001008C7FC000
# Updating information for Imagery ID: 104001008BA6B300
# Updating information for Imagery ID: 104001008C7CFD00
# Updating information for Imagery ID: 104001008D485100
# Updating information for Imagery ID: 104001008BCDCA00
# Updating information for Imagery ID: 104001008CADA700
# Updating information for Imagery ID: 104001008CCF7000
# Updating information for Imagery ID: 104001008B6E3400
# Updating information for Imagery ID: 1040010089D74F00
# Updating information for Imagery ID: 104001008C6DBA00
# Updating information for Imagery ID: 104001008B8CE500
# Updating information for Imagery ID: 104001008C1CE000
# Updating information for Imagery ID: 104001008CBBAD00
# Updating information for Imagery ID: 104001008B630800
# Updating information for Imagery ID: 1040010089A44800
# Updating information for Imagery ID: 10400100883DC200
# Updating information for Imagery ID: 1040010088B6F900
# Updating information for Imagery ID: 1040010088A1D600
# Updating information for Imagery ID: 1040010089CFE300
# Updating information for Imagery ID: 1040010087416200
# Updating information for Imagery ID: 104001008998E300
# Updating information for Imagery ID: 10400100878A6400
# Updating information for Imagery ID: 10400100877FA000
# Updating information for Imagery ID: 104001008A510100
# Updating information for Imagery ID: 1040010088738E00
# Updating information for Imagery ID: 1040010086107C00
# Updating information for Imagery ID: 104001008764D600
# Updating information for Imagery ID: 1040010088500E00
# Updating information for Imagery ID: 1040010087C80800
# Updating information for Imagery ID: 1040010086298400
# Updating information for Imagery ID: 1040010085D2FD00
# Updating information for Imagery ID: 10400100864E7000
# Updating information for Imagery ID: 1040010086080000
# Updating information for Imagery ID: 1040010084ACDF00
# Updating information for Imagery ID: 10400100840A4000
# Updating information for Imagery ID: 104001008501D000
# Updating information for Imagery ID: 1040010083AF0F00
# Updating information for Imagery ID: 1040010085C8B200
# Updating information for Imagery ID: 1040010086BA2B00
# Updating information for Imagery ID: 1040010084CC3900
# Updating information for Imagery ID: 10400100859E2300
# Updating information for Imagery ID: 1040010083C22300
# Updating information for Imagery ID: 10400100837D2A00
# Updating information for Imagery ID: 1040010082744A00
# Updating information for Imagery ID: 1040010084960300
# Updating information for Imagery ID: 104001008360A400
# Updating information for Imagery ID: 104001008251B600
# Updating information for Imagery ID: 1040010083189900
# Updating information for Imagery ID: 1040010083539700
# Updating information for Imagery ID: 104001008242DA00
# Updating information for Imagery ID: 104001007C6D2800
# Updating information for Imagery ID: 104001007657F100
# Updating information for Imagery ID: 1040010075912A00
# Updating information for Imagery ID: 104001007632A100
# Updating information for Imagery ID: 1040010075249700
# Updating information for Imagery ID: 1040010078BEC800
# Updating information for Imagery ID: 104001007789B600
# Updating information for Imagery ID: 10400100750CA600
# Updating information for Imagery ID: 10400100760C3E00
# Updating information for Imagery ID: 10400100745B4300
# Updating information for Imagery ID: 1040010074952C00
# Updating information for Imagery ID: 104001006E807800
# Updating information for Imagery ID: 104001006E756A00
# Updating information for Imagery ID: 104001006E39B400
# Updating information for Imagery ID: 1040010069D83800
# Updating information for Imagery ID: 1040010068C83700
# Updating information for Imagery ID: 104001006700B500
# Updating information for Imagery ID: 104001006A3D0E00
# Updating information for Imagery ID: 1040010068807F00
# Updating information for Imagery ID: 1040010069A92B00
# Updating information for Imagery ID: 1040010069CEBE00
# Updating information for Imagery ID: 1040010068B2B900
# Updating information for Imagery ID: 1040010069828800
# Updating information for Imagery ID: 1040010068262900
# Updating information for Imagery ID: 1040010068651500
# Updating information for Imagery ID: 104001006892A200
# Updating information for Imagery ID: 10400100674B2100
# Updating information for Imagery ID: 1040010067D36B00
# Updating information for Imagery ID: 1040010067015600
# Updating information for Imagery ID: 10400100683A1800
# Updating information for Imagery ID: 10400100653F3D00
# Updating information for Imagery ID: 104001006773EA00
# Updating information for Imagery ID: 10400100654BCC00
# Updating information for Imagery ID: 10400100662FFC00
# Updating information for Imagery ID: 1040010066640300
# Updating information for Imagery ID: 1040010065796C00
# Updating information for Imagery ID: 10400100687EDC00
# Updating information for Imagery ID: 1040010065217400
# Updating information for Imagery ID: 1040010066A36E00
# Updating information for Imagery ID: 1040010066A1F000
# Updating information for Imagery ID: 1040010067CC5D00
# Updating information for Imagery ID: 1040010063561700
# Updating information for Imagery ID: 104001006166E700
# Updating information for Imagery ID: 10400100604B7800
# Updating information for Imagery ID: 1040010060086800
# Updating information for Imagery ID: 104001005F7E5300
# Updating information for Imagery ID: 104001005D070A00
# Updating information for Imagery ID: 104001005C2C4E00
# Updating information for Imagery ID: 104001005D3BDC00
# Updating information for Imagery ID: 104001005B05B600
# Updating information for Imagery ID: 104001005C41D600
# Updating information for Imagery ID: 104001005C159600
# Updating information for Imagery ID: 10400100585EFA00
# Updating information for Imagery ID: 104001005B61D900
# Updating information for Imagery ID: 104001005B16C000
# Updating information for Imagery ID: 104001005322C400
# Updating information for Imagery ID: 10400100539C1800
# Updating information for Imagery ID: 104001005136EA00
# Updating information for Imagery ID: 1040010052606800
# Updating information for Imagery ID: 10400100519C5A00
# Updating information for Imagery ID: 1040010051753000
# Updating information for Imagery ID: 104001004F4F5B00
# Updating information for Imagery ID: 104001004B0CC600
# Updating information for Imagery ID: 104001004AB60600
# Updating information for Imagery ID: 10400100494E4E00
# Updating information for Imagery ID: 104001004A50E800
# Updating information for Imagery ID: 104001004A8CFC00
# Updating information for Imagery ID: 104001004933C100
# Updating information for Imagery ID: 10400100476C3000
# Updating information for Imagery ID: 10400100470C8300
# Updating information for Imagery ID: 104001003EBA6D00
# Updating information for Imagery ID: 104001003F1C4A00
# Updating information for Imagery ID: 104001004040C800
# Updating information for Imagery ID: 104001003D6A7700
# Updating information for Imagery ID: 104001003A19EA00
# Updating information for Imagery ID: 104001003A2DB000
# Updating information for Imagery ID: 10400100395F1100
# Updating information for Imagery ID: 10400100385E2E00
# Updating information for Imagery ID: 1040010035AAED00
# Updating information for Imagery ID: 1040010035BF5F00
# Updating information for Imagery ID: 1040010035167F00
# Updating information for Imagery ID: 10400100294A8900
# Updating information for Imagery ID: 104001002A01D000
# Updating information for Imagery ID: 10400100270D0B00
# Updating information for Imagery ID: 1040010028B2DE00
# Updating information for Imagery ID: 10400100261CD600
# Updating information for Imagery ID: 1040010026AA2900
# Updating information for Imagery ID: 1040010024658700
# Updating information for Imagery ID: 104001000B018B00
# Updating information for Imagery ID: 104001000B626E00
# Updating information for Imagery ID: 104001000ABE7D00
# Updating information for Imagery ID: 1040010009574300
# Updating information for Imagery ID: 1040010008B73800
# Updating information for Imagery ID: 1040010008179700
# Updating information for Imagery ID: 1040010009A2C200
# Updating information for Imagery ID: 1040010002A99600

# %% [markdown]
# ### Select newly inserted AOIs, make a GeoDataFrame for validation

# %%
conn = sqlite3.connect(db)
conn.enable_load_extension(True)
conn.execute("SELECT load_extension('mod_spatialite')")

columns_list = list(gdf.columns[:-1])
columns_str = ', '.join(columns_list)
sql_string = "SELECT {}, AsText(bbox) FROM mgp WHERE id IS NOT NULL AND aoi_id = {}".format(columns_str, aoi_id)

df = pd.read_sql_query(sql_string, conn)
df = df.rename(columns={'AsText(bbox)': 'geometry'}, errors='raise')
df['geometry'] = shapely.wkt.loads(df['geometry'])
gdf = gpd.GeoDataFrame(df, geometry='geometry')

conn.commit()
conn.close()

gdf.head()
# Out:
#                  id      platform instruments       gsd  pan_resolution_avg  \
# 0  1040010093625500  worldview-03        VNIR  0.489590            0.489590
# 1  10400100959B5400  worldview-03        VNIR  0.465732            0.465732
# 2  1040010096672600  worldview-03        VNIR  0.387751            0.387751
# 3  1040010091057E00  worldview-03        VNIR  0.477092            0.477092
# 4  1040010093A5AA00  worldview-03        VNIR  0.400867            0.400867
#
#    multi_resolution_avg                     datetime  off_nadir     azimuth  \
# 0              1.957822  2024-05-10T15:12:09.830632Z  38.731296  298.217210
# 1              1.861867  2024-05-10T15:11:58.030657Z  36.967200  290.060698
# 2              1.566842  2024-05-04T15:18:49.787012Z  28.198752  300.877281
# 3              1.825612  2024-03-14T15:21:50.586824Z  37.508765  332.149348
# 4              1.545379  2024-03-14T15:21:27.286870Z  29.931199  320.083490
#
#    sun_azimuth  sun_elevation  \
# 0   135.970890      59.840196
# 1   136.299460      59.933401
# 2   140.548459      59.617618
# 3   149.478354      41.594089
# 4   149.822968      41.697987
#
#                                                 bbox  \
# 0  b'\x00\x01\x00\x00\x00\x00V\xd8\x0cpA\xa7Q\xc0...
# 1  b'\x00\x01\x00\x00\x00\x00\xb5\xc0\x1e\x13)\x9...
# 2  b'\x00\x01\x00\x00\x00\x00\xe0\xf3\xc3\x08\xe1...
# 3  b'\x00\x01\x00\x00\x00\x00\x89\xb2\xb7\x94\xf3...
# 4  b'\x00\x01\x00\x00\x00\x00\xcdV^\xf2?\x92Q\xc0...
#
#                                             geometry
# 0  POLYGON ((-70.33367 41.78036, -70.33367 42.162...
# 1  POLYGON ((-70.09283 41.80274, -70.09283 42.154...
# 2  POLYGON ((-69.99209 41.46543, -69.99209 42.029...
# 3  POLYGON ((-70.44030 41.77703, -70.44030 42.178...
# 4  POLYGON ((-70.07881 41.79959, -70.07881 42.149...

# %%
# Note that the GDF shape matches that from the above
gdf.shape
# Out:
# (168, 13)

# %% [markdown]
# ### Plot Areas of Interest on an Interactive Map

# %%
def style_function(hex_value):
    return {'color': hex_value, 'fillOpacity': 0}

# Add OpenStreetMap as a basemap
map = folium.Map()
folium.TileLayer('openstreetmap').add_to(map)

# Create a GeoJson layer from the response_geojson and add it to the map
folium.GeoJson(
    gdf['geometry'].to_json(),
    style_function = lambda x: style_function('#0000FF')
).add_to(map)

folium.GeoJson(
    gdf_json,
    style_function = lambda x: style_function('#FF0000')
).add_to(map)

# Zoom to collected images
map.fit_bounds(map.get_bounds(), padding=(100, 100))

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7d992447083501b39e28a33e1ea5d9a5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7d992447083501b39e28a33e1ea5d9a5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7d992447083501b39e28a33e1ea5d9a5 = L.map(
#                 &quot;map_7d992447083501b39e28a33e1ea5d9a5&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f896226344c60a7cc8798792bb057033 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f896226344c60a7cc8798792bb057033.addTo(map_7d992447083501b39e28a33e1ea5d9a5);
#
#
#             var tile_layer_d3e075f5ee72332509c402eda8ba2ff9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d3e075f5ee72332509c402eda8ba2ff9.addTo(map_7d992447083501b39e28a33e1ea5d9a5);
#
#
#         function geo_json_4b110bee1e27105baebae30386ff5c03_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#0000FF&quot;, &quot;fillOpacity&quot;: 0};
#             }
#         }
#
#         function geo_json_4b110bee1e27105baebae30386ff5c03_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_4b110bee1e27105baebae30386ff5c03 = L.geoJson(null, {
#                 onEachFeature: geo_json_4b110bee1e27105baebae30386ff5c03_onEachFeature,
#
#                 style: geo_json_4b110bee1e27105baebae30386ff5c03_styler,
#         });
#
#         function geo_json_4b110bee1e27105baebae30386ff5c03_add (data) {
#             geo_json_4b110bee1e27105baebae30386ff5c03
#                 .addData(data);
#         }
#             geo_json_4b110bee1e27105baebae30386ff5c03_add({&quot;bbox&quot;: [-70.734299, 40.964255, -69.922672, 43.01791], &quot;features&quot;: [{&quot;bbox&quot;: [-70.613369, 41.780362, -70.333672, 42.162377], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-70.333672, 41.780362], [-70.333672, 42.162377], [-70.613369, 42.162377], [-70.613369, 41.780362], [-70.333672, 41.780362]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-70.361882, 41.802739, -70.092829, 42.154464], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-70.092829, 41.802739], [-70.092829, 42.154464], [-70.361882, 42.154464], [-70.361882, 41.802739], [-70.092829, 41.802739]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-70.201235, 41.465429, -69.992088, 42.029869], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-69.992088, 41.465429], [-69.992088, 42.029869], [-70.201235, 42.029869], [-70.201235, 41.465429], [-69.992088, 41.465429]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-70.671117, 41.777031, -70.440299, 42.17897], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-70.440299, 41.777031], [-70.440299, 42.17897], [-70.671117, 42.17897], [-70.671117, 41.777031], [-70.440299, 41.777031]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-70.285153, 41.799586, -70.078809, 42.149836], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-70.078809, 41.799586], [-70.078809, 42.149836], [-70.285153, 42.149836], [-70.285153, 41.799586], [-70.078809, 41.799586]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-70.546477, 41.779481, -70.297866, 42.179218], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-70.297866, 41.779481], [-70.297866, 42.179218], [-70.546477, 42.179218], [-70.546477, 41.779481], [-70.297866, 41.779481]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;5&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-70.327463, 41.787511, -70.092543, 42.154854], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-70.092543, 41.787511], [-70.092543, 42.154854], [-70.327463, 42.15

# %% [markdown]
# # End
